# %%
import pandas as pd
import numpy as np
import pyreadstat
import glob
import os

# .sav 파일 목록
spss_files = glob.glob(r'./data/*.sav')

# 데이터 저장용 딕셔너리
data_dict = {}

# UTF-8 인코딩 기준으로 파일 로딩
for file in spss_files:
    key = os.path.splitext(os.path.basename(file))[0]

    # 데이터 및 메타 정보 읽기
    df, meta = pyreadstat.read_sav(file, encoding='utf-8', apply_value_formats=True)

    # 컬럼 라벨을 데이터프레임 속성으로 저장
    df.attrs['column_labels'] = meta.column_names_to_labels

    # 딕셔너리에 저장
    data_dict[key] = df

    print(f"[성공] {key} 불러오기 완료. shape: {df.shape}")
# Out:
# [성공] 2018_data 불러오기 완료. shape: (16469, 410)
# [성공] 2019_data 불러오기 완료. shape: (16076, 439)
# [성공] 2023_data 불러오기 완료. shape: (16196, 365)
# [성공] 2024_data 불러오기 완료. shape: (16216, 402)

# %%
labels = data_dict['2024_data'].attrs['column_labels']
for col, label in labels.items():
    print(f"{col}: {label}")
# Out:
# pnid: 아이디
# MVIT: 한국 방문횟수(평균)
# RVIT: 한국 방문횟수(카테고리)
# XRVIT: 한국 방문횟수(재방문)
# TYP: 여행 형태
# Q1: 문1. 주요 방한 목적
# Q1_1a1: 문1-1. 한국여행 관심 계기(1순위)
# Q1_1a2: 문1-1. 한국여행 관심 계기(2순위)
# Q1_1a3: 문1-1. 한국여행 관심 계기(3순위)
# Q2a1: 문2. 방문을 고려한 아시아 국가(1순위)
# Q2a2: 문2. 방문을 고려한 아시아 국가(2순위)
# Q2a3: 문2. 방문을 고려한 아시아 국가(3순위)
# Q2a_dk: 문2. 방문을 고려한 아시아 국가(없음)
# Q2_1a1: 문2-1. 해당 국가 관심 계기(1순위)
# Q2_1a2: 문2-1. 해당 국가 관심 계기(2순위)
# Q2_1a3: 문2-1. 해당 국가 관심 계기(3순위)
# ZQ2_31: 문2-2. 한국만 방문(카테고리)
# ZQ2_32: 문2-2. 한국 방문 직전 타 국가 방문(카테고리)
# ZQ2_33: 문2-2. 한국 방문 직후 타 국가 방문(카테고리)
# ZQ2_34: 문2-2. 한국 방문 전후 타 국가 방문(카테고리)
# Q2_3a2at: 문2-2. 한국방문 직전 방문국가
# Q2_3a2bt: 문2-2. 한국방문 직전 방문국가
# Q2_3a2ct: 문2-2. 한국방문 직전 방문국가
# Q2_3a2dt: 문2-2. 한국방문 직전 방문국가
# Q2_3a2et: 문2-2. 한국방문 직전 방문국가
# Q2_3a3at: 문2-2. 한국방문 직후 방문국가
# Q2_3a3bt: 문2-2. 한국방문 직후 방문국가
# Q2_3a3ct: 문2-2. 한국방문 직후 방문국가
# Q2_3a3dt: 문2-2. 한국방문 직후 방문국가
# Q2_3a3et: 문2-2. 한국방문 직후 방문국가
# Q2_3b2a: 문2-2. 한국방문 직전 방문국가(숙박일수)
# Q2_3b2b: 문2-2. 한국방문 직전 방문국가(숙박일수)
# Q2_3b2c: 문2-2. 한국방문 직전 방문국가(숙박일수)
# Q2_3b2d: 문2-2. 한국방문 직전 방문국가(숙박일수)
# Q2_3b2e: 문2-2. 한국방문 직전 방문국가(숙박일수)
# Q2_3b3a: 문2-2. 한국방문 직후 방문국가(숙박일수)
# Q2_3b3b: 문2-2. 한국방문 직후 방문국가(숙박일수)
# Q2_3b3c: 문2-2. 한국방문 직후 방문국가(숙박일수)
# Q2_3b3d: 문2-2. 한국방문 직후 방문국가(숙박일수)
# Q2_3b3e: 문2-2. 한국방문 직후 방문국가(숙박일수)
# Q3_1a1: 문3-1. 고려한 관광활동(1순위)
# Q3_1a2: 문3-1. 고려한 관광활동(2순위)
# Q3_1a3: 문3-1. 고려한 관광활동(3순위)
# Q3_2a1: 문3-2. 고려한 관광인프라(1순위)
# Q3_2a2: 문3-2. 고려한 관광인프라(2순위)
# Q3_2a3: 문3-2. 고려한 관광인프라(3순위)
# Q4a1: 문4. 여행 전 한국 관련 정보 수집 경로(1순위)
# Q4a2: 문4. 여행 전 한국 관련 정보 수집 경로(2순위)
# Q4a3: 문4. 여행 전 한국 관련 정보 수집 경로(3순위)
# Q4a_dk: 문4. 여행 전 한국 관련 정보 수집 경로(없다)
# Q4_1a1: 문4-1. 주로 이용한 사이트(1순위)
# Q4_1a2: 문4-1. 주로 이용한 사이트(2순위)
# Q4_1a3: 문4-1. 주로 이용한 사이트(3순위)
# Q4_2a1: 문4-2. 부족했던 정보(1순위)
# Q4_2a2: 문4-2. 부족했던 정보(2순위)
# Q4_2a3: 문4-2. 부족했던 정보(3순위)
# Q4_2a_dk: 문4-2. 부족했던 정보(없음)
# Q5: 문5. 왕복 항공권 및 여행상품 예약 시기
# Q5_1a01: 문5-1. 개별 예약 항목(1. 숙박시설)
# Q5_1a02: 문5-1. 개별 예약 항목(2. 관광지 예약)
# Q5_1a03: 문5-1. 개별 예약 항목(3. 렌터카)
# Q5_1a04: 문5-1. 개별 예약 항목(4. 철도)
# Q5_1a05: 문5-1. 개별 예약 항목(5. 국내항공권)
# Q5_1a06: 문5-1. 개별 예약 항목(6. 체험 상품)
# Q5_1a07: 문5-1. 개별 예약 항목(7. 공연/관람 티켓)
# Q5_1a08: 문5-1. 개별 예약 항목(8. 식당)
# Q5_1a09: 문5-1. 개별 예약 항목(9. 단기일일투어상품)
# Q5_1a10: 문5-1. 개별 예약 항목(10. 기타)
# Q5_1a_dk: 문5-1. 개별 예약 항목(없음)
# Q6: 문6. 단기일일투어 상품 이용 여부
# Q6_1: 문6. 단기일일투어 상품 이용 여부_기간
# Q6_1R: 문6. 단기일일투어 상품 이용 여부_기간(카테고리)
# Q7A: 문7. 동반자 유무
# Q7a_dk: 문7. 동반자 유형(1. 혼자 방문)
# Q7a2: 문7. 동반자 유형(2. 배우자/파트너)
# Q7a3: 문7. 동반자 유형(3. 부모님)
# Q7a4: 문7. 동반자 유형(4. 자녀)
# Q7a5: 문7. 동반자 유형(5. 그 외 가족/친지)
# Q7a6: 문7. 동반자 유형(6. 친구)
# Q7a7: 문7. 동반자 유형(7. 직장 동료)
# Q7a8: 문7. 동반자 유형(8. 기타)
# MQ7_1: 문7-1. 동반자 수(본인포함)(평균)
# MQ7_1제외: 문7-1. 동반자 수(본인제외)(평균)
# MQ7_2: 문7-1. 동반자 수(만 15세 미만)(평균)
# MQ7_1$15제외: 문7-1. 동반자 수(본인포함, 만 15세 미만 제외)(평균)
# MQ7_1제외$15제외: 문7-1. 동반자 수(본인제외, 만 15세 미만 제외)(평균)
# RQ7_1: 문7-1. 동반자 수(본인포함, 카테고리)
# RQ7_1제외: 문7-1. 동반자 수(본인제외, 카테고리)
# RQ7_2: 문7-1. 동반자 수(만 15세 미만, 카테고리)
# RQ7_1$15제외: 문7-1. 동반자 수(본인포함, 만 15세 미만 제외, 카테고리)
# RQ7_1제외$15제외: 문7-1. 동반자 수(본인제외, 만 15세 미만 제외, 카테고리)
# Q8a01: 문8. 참여한 활동(1. 식도락 관광)
# Q8a02: 문8. 참여한 활동(2. 쇼핑)
# Q8a03: 문8. 참여한 활동(3. 자연경관 감상)
# Q8a04: 문8. 참여한 활동(4. 휴양/휴식(웰니스))
# Q8a05: 문8. 참여한 활동(5. 고궁/역사 유적지 방문)
# Q8a06: 문8. 참여한 활동(6. 전통문화체험)
# Q8a07: 문8. 참여한 활동(7. 박물관, 전시관 관람)
# Q8a08: 문8. 참여한 활동(8. K-POP, 한류스타 관련 공연장 및 드라마/영화 촬영지 방문)
# Q8a09: 문8. 참여한 활동(9. 연극, 뮤지컬, 발레 등 공연 관람)
# Q8a10: 문8. 참여한 활동(10. 지역 축제 참여)
# Q8a11: 문8. 참여한 활동(11. 유흥)
# Q8a12: 문8. 참여한 활동(12. 오락)
# Q8a13: 문8. 참여한 활동(13. 뷰티/미용 관광)
# Q8a14: 문8. 참여한 활동(14. 치료/건강검진)
# Q8a15: 문8. 참여한 활동(15. 스포츠/레포츠 관람)
# Q8a16: 문8. 참여한 활동(16. 스포츠/레포츠 참가)
# Q8a17: 문8. 참여한 활동(17. 국제회의)
# Q8a18: 문8. 참여한 활동(18. 비즈니스 전문활동)
# Q8a19: 문8. 참여한 활동(19. 연수, 교육, 연구)
# Q8a20: 문8. 참여한 활동(20. 기타)
# Q8_1a1: 문8-1. 만족한 활동(1순위)
# Q8_1a2: 문8-1. 만족한 활동(2순위)
# Q8_1a3: 문8-1. 만족한 활동(3순위)
# Q9_1_1: 문9-1. 가장 좋았던 곳 - 1
# Q9_1_2: 문9-1. 가장 좋았던 곳 - 2
# Q9_1_3: 문9-1. 가장 좋았던 곳 - 3
# Q9_1_4: 문9-1. 가장 좋았던 곳 - 4
# Q9_1_5: 문9-1. 가장 좋았던 곳 - 5
# Q9_2a01: 문9-2. 방문 지역(1. 서울)
# Q9_2a02: 문9-2. 방문 지역(2. 경기)
# Q9_2a03: 문9-2. 방문 지역(3. 인천)
# Q9_2a04: 문9-2. 방문 지역(4. 강원)
# Q9_2a05: 문9-2. 방문 지역(5. 대전)
# Q9_2a06: 문9-2. 방문 지역(6. 충북)
# Q9_2a07: 문9-2. 방문 지역(7. 충남)
# Q9_2a08: 문9-2. 방문 지역(8. 세종)
# Q9_2a09: 문9-2. 방문 지역(9. 경북)
# Q9_2a10: 문9-2. 방문 지역(10. 경남)
# Q9_2a11: 문9-2. 방문 지역(11. 대구)
# Q9_2a12: 문9-2. 방문 지역(12. 울산)
# Q9_2a13: 문9-2. 방문 지역(13. 부산)
# Q9_2a14: 문9-2. 방문 지역(14. 광주)
# Q9_2a15: 문9-2. 방문 지역(15. 전북)
# Q9_2a16: 문9-2. 방문 지역(16. 전남)
# Q9_2a17: 문9-2. 방문 지역(17. 제주)
# KWON1: 문9-2. 방문권역(1. 서울)
# KWON2: 문9-2. 방문권역(2. 경기도)
# KWON3: 문9-2. 방문권역(3. 인천)
# KWON4: 문9-2. 방문권역(4. 강원도)
# KWON5: 문9-2. 방문권역(5. 충청도)
# KWON6: 문9-2. 방문권역(6. 경상도)
# KWON7: 문9-2. 방문권역(7. 전라도)
# KWON8: 문9-2. 방문권역(8. 제주)
# KWONA1: 문9-2. 방문권역(수도권 한정)
# KWONA2: 문9-2. 방문권역(지방 한정)
# KWONA3: 문9-2. 방문권역(수도권+지방 모두 방문)
# KWONB1: 문9-2. 방문권역(수도권 방문)
# KWONB2: 문9-2. 방문권역(지방 방문)
# M박HAP: 문9-3. 총 숙박기간
# M일HAP: 문9-3. 총 체재기간
# M일HAP_61: 문9-3. 총 체재기간_61일 이상 결측
# R일HAP: 문9-3. 총 체재기간(카테고리)
# 서울박TOT: 문9-4. 시도별 숙박기간_서울
# 경기박TOT: 문9-4. 시도별 숙박기간_경기
# 인천박TOT: 문9-4. 시도별 숙박기간_인천
# 강원박TOT: 문9-4. 시도별 숙박기간_강원
# 대전박TOT: 문9-4. 시도별 숙박기간_대전
# 충북박TOT: 문9-4. 시도별 숙박기간_충북
# 충남박TOT: 문9-4. 시도별 숙박기간_충남
# 세종박TOT: 문9-4. 시도별 숙박기간_세종
# 경북박TOT: 문9-4. 시도별 숙박기간_경북
# 경남박TOT: 문9-4. 시도별 숙박기간_경남
# 대구박TOT: 문9-4. 시도별 숙박기간_대구
# 울산박TOT: 문9-4. 시도별 숙박기간_울산
# 부산박TOT: 문9-4. 시도별 숙박기간_부산
# 광주박TOT: 문9-4. 시도별 숙박기간_광주
# 전북박TOT: 문9-4. 시도별 숙박기간_전북
# 전남박TOT: 문9-4. 시도별 숙박기간_전남
# 제주박TOT: 문9-4. 시도별 숙박기간_제주
# 서울일TOT: 문9-4. 시도별 체재기간_서울
# 경기일TOT: 문9-4. 시도별 체재기간_경기
# 인천일TOT: 문9-4. 시도별 체재기간_인천
# 강원일TOT: 문9-4. 시도별 체재기간_강원
# 대전일TOT: 문9-4. 시도별 체재기간_대전
# 충북일TOT: 문9-4. 시도별 체재기간_충북
# 충남일TOT: 문9-4. 시도별 체재기간_충남
# 세종일TOT: 문9-4. 시도별 체재기간_세종
# 경북일TOT: 문9-4. 시도별 체재기간_경북
# 경남일TOT: 문9-4. 시도별 체재기간_경남
# 대구일TOT: 문9-4. 시도별 체재기간_대구
# 울산일TOT: 문9-4. 시도별 체재기간_울산
# 부산일TOT: 문9-4. 시도별 체재기간_부산
# 광주일TOT: 문9-4. 시도별 체재기간_광주
# 전북일TOT: 문9-4. 시도별 체재기간_전북
# 전남일TOT: 문9-4. 시도별 체재기간_전남
# 제주일TOT: 문9-4. 시도별 체재기간_제주
# 서울박60: 문9-4. 시도별 숙박기간(60박 이상 결측)_서울
# 경기박60: 문9-4. 시도별 숙박기간(60박 이상 결측)_경기
# 인천박60: 문9-4. 시도별 숙박기간(60박 이상 결측)_인천
# 강원박60: 문9-4. 시도별 숙박기간(60박 이상 결측)_강원
# 대전박60: 문9-4. 시도별 숙박기간(60박 이상 결측)_대전
# 충북박60: 문9-4. 시도별 숙박기간(60박 이상 결측)_충북
# 충남박60: 문9-4. 시도별 숙박기간(60박 이상 결측)_충남
# 세종박60: 문9-4. 시도별 숙박기간(60박 이상 결측)_세종
# 경북박60: 문9-4. 시도별 숙박기간(60박 이상 결측)_경북
# 경남박60: 문9-4. 시도별 숙박기간(60박 이상 결측)_경남
# 대구박60: 문9-4. 시도별 숙박기간(60박 이상 결측)_대구
# 울산박60: 문9-4. 시도별 숙박기간(60박 이상 결측)_울산
# 부산박60: 문9-4. 시도별 숙박기간(60박 이상 결측)_부산
# 광주박60: 문9-4. 시도별 숙박기간(60박 이상 결측)_광주
# 전북박60: 문9-4. 시도별 숙박기간(60박 이상 결측)_전북
# 전남박60: 문9-4. 시도별 숙박기간(60박 이상 결측)_전남
# 제주박60: 문9-4. 시도별 숙박기간(60박 이상 결측)_제주
# 서울일61: 문9-4. 시도별 체재기간(61일 이상 결측)_서울
# 경기일61: 문9-4. 시도별 체재기간(61일 이상 결측)_경기
# 인천일61: 문9-4. 시도별 체재기간(61일 이상 결측)_인천
# 강원일61: 문9-4. 시도별 체재기간(61일 이상 결측)_강원
# 대전일61: 문9-4. 시도별 체재기간(61일 이상 결측)_대전
# 충북일61: 문9-4. 시도별 체재기간(61일 이상 결측)_충북
# 충남일61: 문9-4. 시도별 체재기간(61일 이상 결측)_충남
# 세종일61: 문9-4. 시도별 체재기간(61일 이상 결측)_세종
# 경북일61: 문9-4. 시도별 체재기간(61일 이상 결측)_경북
# 경남일61: 문9-4. 시도별 체재기간(61일 이상 결측)_경남
# 대구일61: 문9-4. 시도별 체재기간(61일 이상 결측)_대구
# 울산일61: 문9-4. 시도별 체재기간(61일 이상 결측)_울산
# 부산일61: 문9-4. 시도별 체재기간(61일 이상 결측)_부산
# 광주일61: 문9-4. 시도별 체재기간(61일 이상 결측)_광주
# 전북일61: 문9-4. 시도별 체재기간(61일 이상 결측)_전북
# 전남일61: 문9-4. 시도별 체재기간(61일 이상 결측)_전남
# 제주일61: 문9-4. 시도별 체재기간(61일 이상 결측)_제주
# WQ9_5a01: 문9-5. 시도별 숙박시설_서울
# WQ9_5a02: 문9-5. 시도별 숙박시설_경기
# WQ9_5a03: 문9-5. 시도별 숙박시설_인천
# WQ9_5a04: 문9-5. 시도별 숙박시설_강원
# WQ9_5a05: 문9-5. 시도별 숙박시설_대전
# WQ9_5a06: 문9-5. 시도별 숙박시설_충북
# WQ9_5a07: 문9-5. 시도별 숙박시설_충남
# WQ9_5a08: 문9-5. 시도별 숙박시설_세종
# WQ9_5a09: 문9-5. 시도별 숙박시설_경북
# WQ9_5a10: 문9-5. 시도별 숙박시설_경남
# WQ9_5a11: 문9-5. 시도별 숙박시설_대구
# WQ9_5a12: 문9-5. 시도별 숙박시설_울산
# WQ9_5a13: 문9-5. 시도별 숙박시설_부산
# WQ9_5a14: 문9-5. 시도별 숙박시설_광주
# WQ9_5a15: 문9-5. 시도별 숙박시설_전북
# WQ9_5a16: 문9-5. 시도별 숙박시설_전남
# WQ9_5a17: 문9-5. 시도별 숙박시설_제주
# Q9_5A1: 문9-5. 주요 이용 숙박시설(1. 호텔)
# Q9_5A2: 문9-5. 주요 이용 숙박시설(2. 모텔/여관)
# Q9_5A3: 문9-5. 주요 이용 숙박시설(3. 콘도미니엄/리조트)
# Q9_5A4: 문9-5. 주요 이용 숙박시설(4. 게스트하우스/호스텔)
# Q9_5A5: 문9-5. 주요 이용 숙박시설(5. 민박/펜션)
# Q9_5A6: 문9-5. 주요 이용 숙박시설(6. 학교/회사 기숙사, 연수원 등)
# Q9_5A7: 문9-5. 주요 이용 숙박시설(7. 친척 또는 친구 집)
# Q9_5A8: 문9-5. 주요 이용 숙박시설(8. 기타)
# Q9_5A9: 문9-5. 주요 이용 숙박시설(9. 숙박하지 않음)
# 호텔숙박: 문9-5. 숙박시설별 숙박기간(1. 호텔)
# 모텔숙박: 문9-5. 숙박시설별 숙박기간(2. 모텔/여관)
# 콘도숙박: 문9-5. 숙박시설별 숙박기간(3. 콘도미니엄/리조트)
# 게스숙박: 문9-5. 숙박시설별 숙박기간(4. 게스트하우스/호스텔)
# 민박숙박: 문9-5. 숙박시설별 숙박기간(5. 민박/펜션)
# 학교숙박: 문9-5. 숙박시설별 숙박기간(6. 학교/회사 기숙사, 연수원 등)
# 친척숙박: 문9-5. 숙박시설별 숙박기간(7. 친척 또는 친구 집)
# 기타숙박: 문9-5. 숙박시설별 숙박기간(8. 기타)
# 호텔숙박60: 문9-5. 숙박시설별 숙박기간(1. 호텔, 60박 이상 결측)
# 모텔숙박60: 문9-5. 숙박시설별 숙박기간(2. 모텔/여관, 60박 이상 결측)
# 콘도숙박60: 문9-5. 숙박시설별 숙박기간(3. 콘도미니엄/리조트, 60박 이상 결측)
# 게스숙박60: 문9-5. 숙박시설별 숙박기간(4. 게스트하우스/호스텔, 60박 이상 결측)
# 민박숙박60: 문9-5. 숙박시설별 숙박기간(5. 민박/펜션, 60박 이상 결측)
# 학교숙박60: 문9-5. 숙박시설별 숙박기간(6. 학교/회사 기숙사, 연수원 등, 60박 이상 결측)
# 친척숙박60: 문9-5. 숙박시설별 숙박기간(7. 친척 또는 친구 집, 60박 이상 결측)
# 기타숙박60: 문9-5. 숙박시설별 숙박기간(8. 기타, 60박 이상 결측)
# 총액1인TOT2: 문10. 1인 지출경비(상하위 1% 대체)
# C총액1인TOT2: 문10. 1인 지출경비(상하위 1% 대체, 카테고리)
# 총액1인TOT_개별국제교통비제외2: 문10. [국제교통비 제외] 1인 지출경비(상하위 1% 대체)
# C총액1인TOT_개별국제교통비제외2: 문10. [국제교통비 제외] 1인 지출경비(상하위 1% 대체, 카테고리)
# MDAY전체TOT_RAW61: 문10. 1인 1일 지출경비(상하위 1% 대체, 61일 이상 결측)
# RDAY전체TOT_RAW61: 문10. 1인 1일 지출경비(상하위 1% 대체, 61일 이상 결측, 카테고리)
# MDAY전체_개별국제교통비제외61: 문10. [국제교통비 제외] 1인 1일 지출경비(상하위 1% 대체, 61일 이상 결측)
# RDAY전체_개별국제교통비제외61: 문10. [국제교통비 제외] 1인 1일 지출경비(상하위 1% 대체, 61일 이상 결측, 카테고리)
# MDAY개별대체61: 문10. 여행형태별 1일 지출경비(개별여행, 상하위 1% 대체, 61일 이상 결측)
# MDAY에어대체61: 문10. 여행형태별 1일 지출경비(Air-tel, 상하위 1% 대체, 61일 이상 결측)
# MDAY단체대체61: 문10. 여행형태별 1일 지출경비(단체여행, 상하위 1% 대체, 61일 이상 결측)
# RDAY개별대체61: 문10. 여행형태별 1일 지출경비(개별여행, 상하위 1% 대체, 61일 이상 결측, 카테고리)
# RDAY에어대체61: 문10. 여행형태별 1일 지출경비(Air-tel, 상하위 1% 대체, 61일 이상 결측, 카테고리)
# RDAY단체대체61: 문10. 여행형태별 1일 지출경비(단체여행, 상하위 1% 대체, 61일 이상 결측, 카테고리)
# MDAY개별대체_개별국제교통비제외61: 문10. [국제교통비 제외] 여행형태별 1일 지출경비(개별여행, 상하위 1% 대체, 61일 이상 결측)
# MDAY에어대체_개별국제교통비제외61: 문10. [국제교통비 제외] 여행형태별 1일 지출경비(Air-tel, 상하위 1% 대체, 61일 이상 결측)
# MDAY단체대체_개별국제교통비제외61: 문10. [국제교통비 제외] 여행형태별 1일 지출경비(단체여행, 상하위 1% 대체, 61일 이상 결측)
# RDAY개별대체_개별국제교통비제외61: 문10. [국제교통비 제외] 여행형태별 1일 지출경비(개별여행, 상하위 1% 대체, 61일 이상 결측, 카테고리)
# RDAY에어대체_개별국제교통비제외61: 문10. [국제교통비 제외] 여행형태별 1일 지출경비(Air-tel, 상하위 1% 대체, 61일 이상 결측, 카테고리)
# RDAY단체대체_개별국제교통비제외61: 문10. [국제교통비 제외] 여행형태별 1일 지출경비(단체여행, 상하위 1% 대체, 61일 이상 결측, 카테고리)
# 여행사1인대체: 문10-1. 항목별 지출경비(1. 여행사 지불비, 영향치 대체)
# 가이드1인대체: 문10-1. 항목별 지출경비(2. 가이드비, 영향치 대체)
# 숙박비1인대체: 문10-1. 항목별 지출경비(3. 숙박비, 영향치 대체)
# 음식점1인대체: 문10-1. 항목별 지출경비(4. 음식점 지출비, 영향치 대체)
# 식음료1인대체: 문10-1. 항목별 지출경비(5. 식재료비, 영향치 대체)
# 국제한국1인대체: 문10-1. 항목별 지출경비(6. 국제교통_국적기, 영향치 대체)
# 국제국외1인대체: 문10-1. 항목별 지출경비(7. 국제교통_국적기 외, 영향치 대체)
# 국제수상1인대체: 문10-1. 항목별 지출경비(8. 국제교통_수상여객, 영향치 대체)
# 한국한국1인대체: 문10-1. 항목별 지출경비(9. 국내교통_국적기, 영향치 대체)
# 한국국외1인대체: 문10-1. 항목별 지출경비(10. 국내교통_국적기 외, 영향치 대체)
# 한국수상1인대체: 문10-1. 항목별 지출경비(11. 국내교통_수상여객, 영향치 대체)
# 한국철도1인대체: 문10-1. 항목별 지출경비(12. 국내교통_철도여객, 영향치 대체)
# 한국도로1인대체: 문10-1. 항목별 지출경비(13. 국내교통_도로여객, 영향치 대체)
# 대여서1인대체: 문10-1. 항목별 지출경비(14. 렌터카, 영향치 대체)
# 유류비1인대체: 문10-1. 항목별 지출경비(15. 유류비, 영향치 대체)
# 문화서1인대체: 문10-1. 항목별 지출경비(16. 문화서비스, 영향치 대체)
# 오락및1인대체: 문10-1. 항목별 지출경비(17. 오락 및 운동, 영향치 대체)
# 쇼핑비1인대체: 문10-1. 항목별 지출경비(18. 쇼핑비, 영향치 대체)
# 데이터1인대체: 문10-1. 항목별 지출경비(19. 데이터 통신비, 영향치 대체)
# 치료및1인대체: 문10-1. 항목별 지출경비(20. 치료 및 건강검진비, 영향치 대체)
# 미용서1인대체: 문10-1. 항목별 지출경비(21. 미용 서비스비, 영향치 대체)
# 기타비1인대체: 문10-1. 항목별 지출경비(22. 기타 비용, 영향치 대체)
# 단기투어상품1인대체: 문10-1. 항목별 지출경비(23. 여행사 지불비(단기투어상품비), 영향치 대체)
# C여행사1인대체: 문10-1. 항목별 지출경비(1. 여행사 지불비, 영향치 대체, 카테고리)
# C가이드1인대체: 문10-1. 항목별 지출경비(2. 가이드비, 영향치 대체, 카테고리)
# C숙박비1인대체: 문10-1. 항목별 지출경비(3. 숙박비, 영향치 대체, 카테고리)
# C음식점1인대체: 문10-1. 항목별 지출경비(4. 음식점 지출비, 영향치 대체, 카테고리)
# C식음료1인대체: 문10-1. 항목별 지출경비(5. 식재료비, 영향치 대체, 카테고리)
# C국제한국1인대체: 문10-1. 항목별 지출경비(6. 국제교통_국적기, 영향치 대체, 카테고리)
# C국제국외1인대체: 문10-1. 항목별 지출경비(7. 국제교통_국적기 외, 영향치 대체, 카테고리)
# C국제수상1인대체: 문10-1. 항목별 지출경비(8. 국제교통_수상여객, 영향치 대체, 카테고리)
# C한국한국1인대체: 문10-1. 항목별 지출경비(9. 국내교통_국적기, 영향치 대체, 카테고리)
# C한국국외1인대체: 문10-1. 항목별 지출경비(10. 국내교통_국적기 외, 영향치 대체, 카테고리)
# C한국수상1인대체: 문10-1. 항목별 지출경비(11. 국내교통_수상여객, 영향치 대체, 카테고리)
# C한국철도1인대체: 문10-1. 항목별 지출경비(12. 국내교통_철도여객, 영향치 대체, 카테고리)
# C한국도로1인대체: 문10-1. 항목별 지출경비(13. 국내교통_도로여객, 영향치 대체, 카테고리)
# C대여서1인대체: 문10-1. 항목별 지출경비(14. 렌터카, 영향치 대체, 카테고리)
# C유류비1인대체: 문10-1. 항목별 지출경비(15. 유류비, 영향치 대체, 카테고리)
# C문화서1인대체: 문10-1. 항목별 지출경비(16. 문화서비스, 영향치 대체, 카테고리)
# C오락및1인대체: 문10-1. 항목별 지출경비(17. 오락 및 운동, 영향치 대체, 카테고리)
# C쇼핑비1인대체: 문10-1. 항목별 지출경비(18. 쇼핑비, 영향치 대체, 카테고리)
# C데이터1인대체: 문10-1. 항목별 지출경비(19. 데이터 통신비, 영향치 대체, 카테고리)
# C치료및1인대체: 문10-1. 항목별 지출경비(20. 치료 및 건강검진비, 영향치 대체, 카테고리)
# C미용서1인대체: 문10-1. 항목별 지출경비(21. 미용 서비스비, 영향치 대체, 카테고리)
# C기타비1인대체: 문10-1. 항목별 지출경비(22. 기타 비용, 영향치 대체, 카테고리)
# C단기투어상품1인대체: 문10-1. 항목별 지출경비(23. 여행사 지불비(단기투어상품비), 영향치 대체, 카테고리)
# Q10_2a01: 문10-2. 쇼핑 항목(1. 향수, 화장품)
# Q10_2a02: 문10-2. 쇼핑 항목(2. 식료품)
# Q10_2a03: 문10-2. 쇼핑 항목(3. 의류)
# Q10_2a04: 문10-2. 쇼핑 항목(4. 신발류)
# Q10_2a05: 문10-2. 쇼핑 항목(5. 가방류)
# Q10_2a06: 문10-2. 쇼핑 항목(6. 보석/악세서리)
# Q10_2a07: 문10-2. 쇼핑 항목(7. 인삼, 한약재)
# Q10_2a08: 문10-2. 쇼핑 항목(8. 주류)
# Q10_2a09: 문10-2. 쇼핑 항목(9. 담배)
# Q10_2a10: 문10-2. 쇼핑 항목(10. 전통 민예품, 칠기, 목각제품)
# Q10_2a11: 문10-2. 쇼핑 항목(11. 한류 스타 관련상품)
# Q10_2a12: 문10-2. 쇼핑 항목(12. 전자제품)
# Q10_2a13: 문10-2. 쇼핑 항목(13. 기타)
# MQ10_2b01: 문10-2. 쇼핑 항목별 비중(1. 향수, 화장품)
# MQ10_2b02: 문10-2. 쇼핑 항목별 비중(2. 식료품)
# MQ10_2b03: 문10-2. 쇼핑 항목별 비중(3. 의류)
# MQ10_2b04: 문10-2. 쇼핑 항목별 비중(4. 신발류)
# MQ10_2b05: 문10-2. 쇼핑 항목별 비중(5. 가방류)
# MQ10_2b06: 문10-2. 쇼핑 항목별 비중(6. 보석/악세서리)
# MQ10_2b07: 문10-2. 쇼핑 항목별 비중(7. 인삼, 한약재)
# MQ10_2b08: 문10-2. 쇼핑 항목별 비중(8. 주류)
# MQ10_2b09: 문10-2. 쇼핑 항목별 비중(9. 담배)
# MQ10_2b10: 문10-2. 쇼핑 항목별 비중(10. 전통 민예품, 칠기, 목각제품)
# MQ10_2b11: 문10-2. 쇼핑 항목별 비중(11. 한류 스타 관련상품)
# MQ10_2b12: 문10-2. 쇼핑 항목별 비중(12. 전자제품)
# MQ10_2b13: 문10-2. 쇼핑 항목별 비중(13. 기타)
# Q10_3a1: 문10-3. 쇼핑 장소(1순위)
# Q10_3a2: 문10-3. 쇼핑 장소(2순위)
# Q10_3a3: 문10-3. 쇼핑 장소(3순위)
# Q11: 문11. 전반적 만족도
# Q12a01: 문12. 항목별 만족도(1. 식도락)
# Q12a02: 문12. 항목별 만족도(2. 쇼핑)
# Q12a03: 문12. 항목별 만족도(3. 자연경관 감상)
# Q12a04: 문12. 항목별 만족도(4. 휴양/휴식(웰니스)
# Q12a05: 문12. 항목별 만족도(5. 고궁/역사 유적지 방문)
# Q12a06: 문12. 항목별 만족도(6. 전통문화체험)
# Q12a07: 문12. 항목별 만족도(7. 박물관, 전시관 관람)
# Q12a08: 문12. 항목별 만족도(8. K-POP/한류스타 관련 공연장 및 드라마/영화 촬영지 방문)
# Q12a09: 문12. 항목별 만족도(9. 연극, 뮤지컬, 발레 등 공연 관람)
# Q12a10: 문12. 항목별 만족도(10. 지역 축제 참여)
# Q12a11: 문12. 항목별 만족도(11. 유흥)
# Q12a12: 문12. 항목별 만족도(12. 오락)
# Q12a13: 문12. 항목별 만족도(13. 뷰티/미용 관광)
# Q12a14: 문12. 항목별 만족도(14. 치료/건강검진)
# Q12a15: 문12. 항목별 만족도(15. 스포츠/레포츠 관람)
# Q12a16: 문12. 항목별 만족도(16. 스포츠/레포츠 참가)
# Q12a17: 문12. 항목별 만족도(17. 출입국 절차)
# Q12a18: 문12. 항목별 만족도(18. 언어소통)
# Q12a19: 문12. 항목별 만족도(19. 치안)
# Q12a20: 문12. 항목별 만족도(20. 여행 경비)
# Q12a21: 문12. 항목별 만족도(21. 숙박 시설)
# Q12a22: 문12. 항목별 만족도(22. 대중교통/교통)
# Q12a23: 문12. 항목별 만족도(23. 길찾기)
# Q12a24: 문12. 항목별 만족도(24. 관광안내서비스)
# Q12a25: 문12. 항목별 만족도(25. 모바일/인터넷이용 편의)
# Q12a26: 문12. 항목별 만족도(26. 디지털 관광 정보)
# Q12a27: 문12. 항목별 만족도(27. 한국여행사/가이드)
# Q13: 문13. 재방문 의사
# Q14: 문14. 타인 추천 의향
# D_MON:  ▩ 월              별 ▩
# D_BUN:  ▩ 분      기      별 ▩
# D_NAT:  ▩ 국      가      별 ▩
# D_NAT2:  ▩ 국  가  별(중동) ▩
# D_SEX:  ▩ 성              별 ▩
# D_AGE:  ▩ 연      령      별 ▩
# D_MOK:  ▩ 방  한  목  적  별 ▩
# D_NUM:  ▩ 방  한  횟  수  별 ▩
# D_GUB:  ▩ 여  행  형  태  별 ▩
# weight1: 1분기 가중치
# weight2: 2분기 가중치
# weight3: 3분기 가중치
# weight4: 4분기 가중치
# weight: ★1~4분기 전체 가중치

# %%
# 분석에 쓸만한 데이터 
# 월별, 분기별, 국가별, 성별, 연령별, 방한목적별, 방한횟수별, 여행형태별
# 2023~2024
temp_11 = ['pnid', 'D_MON', 'D_BUN', 'D_NAT', 'D_SEX', 'D_AGE', 'D_MOK', 'D_NUM', 'D_GUB']
# 2021~2022
temp_12 = ['id', 'D_MON', 'D_BUN', 'D_NAT', 'D_SEX', 'D_AGE', 'D_MOK', 'D_Q1', 'D_TYP']
# 2019~2020
temp_13 = ['ID', 'D_MON', 'D_QUA', 'D_COU1', 'D_GEN', 'D_AGE', 'D_Q5_1', 'D_Q1', 'D_Q12']
# 2018
temp_14 = ['ID', 'D_MON', 'D_QUA', 'D_COU', 'D_GEN', 'D_AGE', 'D_Q5_1', 'D_Q1', 'D_Q13']

# 변수명 통일
temp_1_columns = ['ID', 'month', 'quarter', 'country', 'gender', 'age', 'visit_purpose', 'num_visits', 'travel_type']

# 연도별 데이터 키와 temp 키 매핑
year_temp_map = {
    2024: temp_11,
    2023: temp_11,
    # 2022: temp_12,
    # 2021: temp_12,
    # 2020: temp_13,
    2019: temp_13,
    2018: temp_14
}

# 가공된 데이터프레임을 저장할 리스트
df_list = []

for year, temp_key in year_temp_map.items():
    df = data_dict[f'{year}_data'][temp_key].copy()
    df.columns = temp_1_columns
    df['year'] = year
    df_list.append(df)

# 모든 연도 데이터 결합
temp_1_df = pd.concat(df_list, ignore_index=True)
temp_1_df
# Out:
#            ID                  month               quarter  \
# 0        57.0      1               월      1       분      기
# 1        58.0      1               월      1       분      기
# 2        59.0      1               월      1       분      기
# 3        60.0      1               월      1       분      기
# 4        61.0      1               월      1       분      기
# ...       ...                    ...                   ...
# 64952  9004.0      6               월      2       분      기
# 64953  9004.0      7               월      3       분      기
# 64954  9004.0      8               월      3       분      기
# 64955  9004.0      11              월      4       분      기
# 64956  9004.0      12              월      4       분      기
#
#                     country                gender                    age  \
# 0             인  도  네  시  아      여              성      50              대
# 1          대              만      여              성      40              대
# 2          대              만      여              성      30              대
# 3          중              국      남              성      20              대
# 4          대              만      여              성      20              대
# ...                     ...                   ...                    ...
# 64952      일              본      여              성      51    -    60   세
# 64953      일              본      여              성      41    -    50   세
# 64954      일              본      여              성      51    -    60   세
# 64955      일              본      여              성      51    -    60   세
# 64956      일              본      여              성        61   세   이    상
#
#           visit_purpose             num_visits         travel_type  year
# 0          여 가/위 락/ 휴 식        4    회    이   상      개   별    여   행  2024
# 1          여 가/위 락/ 휴 식        4    회    이   상      개   별    여   행  2024
# 2          여 가/위 락/ 휴 식      3               회      개   별    여   행  2024
# 3          여 가/위 락/ 휴 식      1               회      개   별    여   행  2024
# 4          여 가/위 락/ 휴 식        4    회    이   상      개   별    여   행  2024
# ...                 ...                    ...                 ...   ...
# 64952      여 가/위 락/ 휴 식      1               회      단   체    여   행  2018
# 64953      여 가/위 락/ 휴 식      1               회      단   체    여   행  2018
# 64954      여 가/위 락/ 휴 식      1               회      단   체    여   행  2018
# 64955      여 가/위 락/ 휴 식        4   회     이   상      개   별    여   행  2018
# 64956      여 가/위 락/ 휴 식        4   회     이   상      단   체    여   행  2018
#
# [64957 rows x 10 columns]

# %%
# 만족도, 재방문의사, 타인 추천 의향
# 2023~2024
temp_21 = ['pnid', 'Q11', 'Q13', 'Q14']
# 2021~2022
temp_22 = ['id', 'Q7', 'Q8', 'Q9']
# 2018~2020
temp_23 = ['ID', 'Q15_1', 'Q16', 'Q17']

# 변수명 통일
temp_2_columns = ['ID', 'satisfaction', 'revisit_intent', 'recommend_intent']

# 연도별 데이터 키와 temp 키 매핑
year_temp_map = {
    2024: temp_21,
    2023: temp_21,
    # 2022: temp_22,
    # 2021: temp_22,
    # 2020: temp_23,
    2019: temp_23,
    2018: temp_23,
}

# 가공된 데이터프레임을 저장할 리스트
df_list = []

for year, temp_key in year_temp_map.items():
    df = data_dict[f'{year}_data'][temp_key].copy()
    df.columns = temp_2_columns
    df['year'] = year
    df_list.append(df)

# 모든 연도 데이터 결합
temp_2_df = pd.concat(df_list, ignore_index=True)
temp_2_df
# Out:
#            ID satisfaction revisit_intent recommend_intent  year
# 0        57.0      ⑤ 매우 만족       ⑤ 매우 그렇다         ⑤ 매우 그렇다  2024
# 1        58.0      ⑤ 매우 만족       ⑤ 매우 그렇다         ⑤ 매우 그렇다  2024
# 2        59.0         ④ 만족      ④ 대체로 그렇다        ④ 대체로 그렇다  2024
# 3        60.0      ⑤ 매우 만족       ⑤ 매우 그렇다         ⑤ 매우 그렇다  2024
# 4        61.0         ④ 만족       ⑤ 매우 그렇다         ⑤ 매우 그렇다  2024
# ...       ...          ...            ...              ...   ...
# 64952  9004.0     ④ 대체로 만족      ④ 대체로 그렇다        ④ 대체로 그렇다  2018
# 64953  9004.0      ⑤ 매우 만족       ⑤ 매우 그렇다         ⑤ 매우 그렇다  2018
# 64954  9004.0      ⑤ 매우 만족       ⑤ 매우 그렇다         ⑤ 매우 그렇다  2018
# 64955  9004.0      ⑤ 매우 만족       ⑤ 매우 그렇다         ⑤ 매우 그렇다  2018
# 64956  9004.0      ⑤ 매우 만족       ⑤ 매우 그렇다         ⑤ 매우 그렇다  2018
#
# [64957 rows x 5 columns]

# %%
# 방문권역, 숙박기간, 체재기간
# 2023~2024
temp_31 = ['pnid', 'KWON1', 'KWON2', 'KWON3', 'KWON4', 'KWON5', 'KWON6', 'KWON7', 'KWON8', 'M박HAP', 'M일HAP']
# 2021~2022
temp_32 = ['id', 'KWON1', 'KWON2', 'KWON3', 'KWON4', 'KWON5', 'KWON6', 'KWON7', 'KWON8', 'Q2a1', 'Q2a2']
# 2019~2020
temp_33 = ['ID', 'Q10_1C1', 'Q10_1C2', 'Q10_1C3', 'Q10_1C4', 'Q10_1C5', 'Q10_1C6', 'Q10_1C7', 'Q10_1C8', 'Q10_6A1', 'Q10_6A2']
# 2018
temp_34 = ['ID', 'Q10_1B1', 'Q10_1B2', 'Q10_1B3', 'Q10_1B4', 'Q10_1B5', 'Q10_1B6', 'Q10_1B7', 'Q10_1B8', 'Q10_3A1', 'Q10_3A2']

# 변수명 통일
temp_3_columns = ['ID', 'seoul', 'gyeonggi', 'incheon', 'gangwon', 'chungcheong', 'gyeongsang', 'jeolla', 'jeju', 'stay_duration', 'total_duration']

# 연도별 데이터 키와 temp 키 매핑
year_temp_map = {
    2024: temp_31,
    2023: temp_31,
    # 2022: temp_32,
    # 2021: temp_32,
    # 2020: temp_33,
    2019: temp_33,
    2018: temp_34
}

# 가공된 데이터프레임을 저장할 리스트
df_list = []

for year, temp_key in year_temp_map.items():
    df = data_dict[f'{year}_data'][temp_key].copy()
    df.columns = temp_3_columns
    df['year'] = year
    df_list.append(df)

# 모든 연도 데이터 결합
temp_3_df = pd.concat(df_list, ignore_index=True)
temp_3_df
# Out:
#            ID seoul gyeonggi incheon gangwon chungcheong gyeongsang jeolla  \
# 0        57.0    서울      NaN     NaN     NaN         NaN        NaN    NaN
# 1        58.0    서울      NaN     NaN     NaN         NaN        NaN    NaN
# 2        59.0    서울      NaN     NaN     NaN         NaN        NaN    NaN
# 3        60.0    서울      NaN     NaN     NaN         NaN        NaN    NaN
# 4        61.0    서울      경기도     NaN     NaN         NaN        NaN    NaN
# ...       ...   ...      ...     ...     ...         ...        ...    ...
# 64952  9004.0   NaN      NaN     NaN     NaN         NaN         경상    NaN
# 64953  9004.0   NaN      NaN     NaN     NaN         NaN         경상    NaN
# 64954  9004.0   NaN      NaN     NaN     NaN         NaN         경상    NaN
# 64955  9004.0   NaN      NaN     NaN     NaN         NaN         경상    NaN
# 64956  9004.0   NaN      NaN     NaN     NaN         NaN         경상    NaN
#
#       jeju  stay_duration  total_duration  year
# 0      NaN            5.0             6.0  2024
# 1      NaN            4.0             5.0  2024
# 2      NaN            5.0             6.0  2024
# 3      NaN            5.0             6.0  2024
# 4      NaN            4.0             5.0  2024
# ...    ...            ...             ...   ...
# 64952  NaN            3.0             4.0  2018
# 64953  NaN            3.0             4.0  2018
# 64954  NaN            2.0             3.0  2018
# 64955  NaN            3.0             4.0  2018
# 64956  NaN            2.0             3.0  2018
#
# [64957 rows x 12 columns]

# %%
# 고려한 관광 활동 (1순위)
# 2023~2024
temp_41 = ['pnid', 'Q3_1a1']
# 2018~2020
temp_42 = ['ID', 'Q5_2A1']

# 변수명 통일
temp_4_columns = ['ID', 'planned_activity']

# 연도별 데이터 키와 temp 키 매핑
year_temp_map = {
    2024: temp_41,
    2023: temp_41,
    # 2020: temp_53,
    2019: temp_42,
    2018: temp_42
}

# 가공된 데이터프레임을 저장할 리스트
df_list = []

for year, temp_key in year_temp_map.items():
    df = data_dict[f'{year}_data'][temp_key].copy()
    df.columns = temp_4_columns
    df['year'] = year
    df_list.append(df)

# 모든 연도 데이터 결합
temp_4_df = pd.concat(df_list, ignore_index=True)
temp_4_df
# Out:
#            ID         planned_activity  year
# 0        57.0            식도락(음식/미식) 관광  2024
# 1        58.0      유흥(나이트라이프 활동 및 카지노)  2024
# 2        59.0      오락(놀이공원 및 테마파크 방문 등  2024
# 3        60.0      유흥(나이트라이프 활동 및 카지노)  2024
# 4        61.0            식도락(음식/미식) 관광  2024
# ...       ...                      ...   ...
# 64952  9004.0                 음식/미식 탐방  2018
# 64953  9004.0                 음식/미식 탐방  2018
# 64954  9004.0  템플스테이 태권도 등 한국 전통 문화 체험  2018
# 64955  9004.0                 음식/미식 탐방  2018
# 64956  9004.0                 음식/미식 탐방  2018
#
# [64957 rows x 3 columns]

# %%
# 인당 지출 경비 (비중을 구해볼 것, 숙박, 식음료비, 쇼핑비)
# 2023~2024
temp_51 = ['pnid', '총액1인TOT2', '숙박비1인대체', '음식점1인대체', '쇼핑비1인대체']
# 2021~2022
temp_52 = ['id', '총액1인TOT', '', '', '']
# 2018~2020
temp_53 = ['ID', 'Q14_1T', 'Q14_2_1', 'Q14_2_3', 'Q14_2_4']

# 변수명 통일
temp_5_columns = ['ID', 'total_expense', 'accommodation_cost', 'food_cost', 'shopping_cost']

# 연도별 데이터 키와 temp 키 매핑
year_temp_map = {
    2024: temp_51,
    2023: temp_51,
    # 2020: temp_53,
    2019: temp_53,
    2018: temp_53
}

# 가공된 데이터프레임을 저장할 리스트
df_list = []

for year, temp_key in year_temp_map.items():
    df = data_dict[f'{year}_data'][temp_key].copy()
    df.columns = temp_5_columns
    df['year'] = year
    df_list.append(df)

# 모든 연도 데이터 결합
temp_5_df = pd.concat(df_list, ignore_index=True)
temp_5_df
# Out:
#            ID  total_expense  accommodation_cost   food_cost  shopping_cost  \
# 0        57.0      2710.0000         1000.000000  500.000000     500.000000
# 1        58.0      1364.6750          202.462020  121.477212     485.908848
# 2        59.0      1065.9000          161.475534  161.475534     322.951068
# 3        60.0       922.6800          279.177005  209.382753     139.588502
# 4        61.0      1647.3000          161.468340   32.293668     968.810037
# ...       ...            ...                 ...         ...            ...
# 64952  9004.0       601.1940                 NaN  163.962000      91.090000
# 64953  9004.0       595.8480                 NaN  162.504000      45.140000
# 64954  9004.0       518.4040                 NaN  151.946000      62.566000
# 64955  9004.0       390.3471          182.161980   86.743800      86.743800
# 64956  9004.0       529.8156                 NaN  176.605200      44.151300
#
#        year
# 0      2024
# 1      2024
# 2      2024
# 3      2024
# 4      2024
# ...     ...
# 64952  2018
# 64953  2018
# 64954  2018
# 64955  2018
# 64956  2018
#
# [64957 rows x 6 columns]

# %%
# 항목별 만족도 (식도락, 자연경관, 역사유적지, 언어소통, 치안, 여행경비, 숙박시설, 대중교통, 길찾기)
# 2023~2024
temp_61 = ['pnid', 'Q12a01', 'Q12a03', 'Q12a05', 'Q12a18', 'Q12a19', 'Q12a20', 'Q12a21', 'Q12a22', 'Q12a23']
# 2021~2022
temp_62 = ['', '', '', '', '', '', '', '', ''] # 없음
# 2018~2020
# 음식, 관광지 매력도, 언어소통, 치안, 여행경비, 숙박, 대중교통, 길찾기
temp_63 = ['ID', 'Q15_2A5', 'Q15_2A8', 'Q15_2A8', 'Q15_2A9', 'Q15_2A11', 'Q15_2A10', 'Q15_2A4', 'Q15_2A2', 'Q15_2A3']

# 변수명 통일
temp_6_columns = ['ID', 'food', 'landscape', 'heritage', 'language', 'safety', 'budget', 'accommodation', 'transport', 'navigation']

# 연도별 데이터 키와 temp 키 매핑
year_temp_map = {
    2024: temp_61,
    2023: temp_61,
    # 2020: temp_63,
    2019: temp_63,
    2018: temp_63
}

# 가공된 데이터프레임을 저장할 리스트
df_list = []

for year, temp_key in year_temp_map.items():
    df = data_dict[f'{year}_data'][temp_key].copy()
    df.columns = temp_6_columns
    df['year'] = year
    df_list.append(df)

# 모든 연도 데이터 결합
temp_6_df = pd.concat(df_list, ignore_index=True)
temp_6_df
# Out:
#            ID      food landscape  heritage   language    safety   budget  \
# 0        57.0       NaN   ⑤ 매우 만족       NaN    ⑤ 매우 만족   ⑤ 매우 만족  ⑤ 매우 만족
# 1        58.0   ⑤ 매우 만족       NaN      ④ 만족       ④ 만족      ④ 만족     ④ 만족
# 2        59.0   ⑤ 매우 만족       NaN       NaN       ③ 보통   ⑤ 매우 만족  ⑤ 매우 만족
# 3        60.0   ⑤ 매우 만족   ⑤ 매우 만족   ⑤ 매우 만족    ⑤ 매우 만족   ⑤ 매우 만족  ⑤ 매우 만족
# 4        61.0       NaN       NaN      ④ 만족       ③ 보통      ④ 만족     ④ 만족
# ...       ...       ...       ...       ...        ...       ...      ...
# 64952  9004.0   ⑤ 매우 만족  ④ 대체로 만족  ④ 대체로 만족   ④ 대체로 만족   ⑤ 매우 만족  ⑤ 매우 만족
# 64953  9004.0  ④ 대체로 만족   ⑤ 매우 만족   ⑤ 매우 만족    ⑤ 매우 만족   ⑤ 매우 만족  ⑤ 매우 만족
# 64954  9004.0   ⑤ 매우 만족  ④ 대체로 만족  ④ 대체로 만족    ⑤ 매우 만족   ⑤ 매우 만족  ⑤ 매우 만족
# 64955  9004.0   ⑤ 매우 만족   ⑤ 매우 만족   ⑤ 매우 만족    ⑤ 매우 만족   ⑤ 매우 만족  ⑤ 매우 만족
# 64956  9004.0  ④ 대체로 만족   ⑤ 매우 만족   ⑤ 매우 만족  ② 대체로 불만족  ④ 대체로 만족  ⑤ 매우 만족
#
#       accommodation transport navigation  year
# 0           ⑤ 매우 만족   ⑤ 매우 만족    ⑤ 매우 만족  2024
# 1              ④ 만족      ④ 만족       ④ 만족  2024
# 2           ⑤ 매우 만족   ⑤ 매우 만족       ③ 보통  2024
# 3           ⑤ 매우 만족   ⑤ 매우 만족    ⑤ 매우 만족  2024
# 4              ④ 만족      ④ 만족       ③ 보통  2024
# ...             ...       ...        ...   ...
# 64952       ⑤ 매우 만족  ④ 대체로 만족    ⑤ 매우 만족  2018
# 64953      ④ 대체로 만족   ⑤ 매우 만족   ④ 대체로 만족  2018
# 64954       ⑤ 매우 만족  ④ 대체로 만족    ⓞ 해당 없음  2018
# 64955          ③ 보통   ⑤ 매우 만족    ⑤ 매우 만족  2018
# 64956          ③ 보통  ④ 대체로 만족   ④ 대체로 만족  2018
#
# [64957 rows x 11 columns]

# %%
# 데이터 전체
total_columns = temp_1_columns + temp_2_columns + temp_3_columns + temp_4_columns + temp_5_columns + temp_6_columns

# 연도별 데이터 키와 temp 키 매핑
year_temp_map = {
    2024: temp_11 + temp_21 + temp_31 + temp_41 + temp_51 + temp_61,
    2023: temp_11 + temp_21 + temp_31 + temp_41 + temp_51 + temp_61,
    # 2020: temp_13 + temp_23 + temp_33 + temp_53 + temp_63,
    2019: temp_13 + temp_23 + temp_33 + temp_42 + temp_53 + temp_63,
    2018: temp_14 + temp_23 + temp_34 + temp_42 + temp_53 + temp_63
}

# 가공된 데이터프레임을 저장할 리스트
df_list = []

for year, temp_key in year_temp_map.items():
    df = data_dict[f'{year}_data'][temp_key].copy()
    df.columns = total_columns
    df['year'] = year
    df_list.append(df)

# 모든 연도 데이터 결합
total_df = pd.concat(df_list, ignore_index=True)
total_df = total_df.loc[:, ~total_df.columns.duplicated()]
total_df
# Out:
#            ID                  month               quarter  \
# 0        57.0      1               월      1       분      기
# 1        58.0      1               월      1       분      기
# 2        59.0      1               월      1       분      기
# 3        60.0      1               월      1       분      기
# 4        61.0      1               월      1       분      기
# ...       ...                    ...                   ...
# 64952  9004.0      6               월      2       분      기
# 64953  9004.0      7               월      3       분      기
# 64954  9004.0      8               월      3       분      기
# 64955  9004.0      11              월      4       분      기
# 64956  9004.0      12              월      4       분      기
#
#                     country                gender                    age  \
# 0             인  도  네  시  아      여              성      50              대
# 1          대              만      여              성      40              대
# 2          대              만      여              성      30              대
# 3          중              국      남              성      20              대
# 4          대              만      여              성      20              대
# ...                     ...                   ...                    ...
# 64952      일              본      여              성      51    -    60   세
# 64953      일              본      여              성      41    -    50   세
# 64954      일              본      여              성      51    -    60   세
# 64955      일              본      여              성      51    -    60   세
# 64956      일              본      여              성        61   세   이    상
#
#           visit_purpose             num_visits         travel_type  \
# 0          여 가/위 락/ 휴 식        4    회    이   상      개   별    여   행
# 1          여 가/위 락/ 휴 식        4    회    이   상      개   별    여   행
# 2          여 가/위 락/ 휴 식      3               회      개   별    여   행
# 3          여 가/위 락/ 휴 식      1               회      개   별    여   행
# 4          여 가/위 락/ 휴 식        4    회    이   상      개   별    여   행
# ...                 ...                    ...                 ...
# 64952      여 가/위 락/ 휴 식      1               회      단   체    여   행
# 64953      여 가/위 락/ 휴 식      1               회      단   체    여   행
# 64954      여 가/위 락/ 휴 식      1               회      단   체    여   행
# 64955      여 가/위 락/ 휴 식        4   회     이   상      개   별    여   행
# 64956      여 가/위 락/ 휴 식        4   회     이   상      단   체    여   행
#
#       satisfaction  ...      food landscape  heritage   language    safety  \
# 0          ⑤ 매우 만족  ...       NaN   ⑤ 매우 만족       NaN    ⑤ 매우 만족   ⑤ 매우 만족
# 1          ⑤ 매우 만족  ...   ⑤ 매우 만족       NaN      ④ 만족       ④ 만족      ④ 만족
# 2             ④ 만족  ...   ⑤ 매우 만족       NaN       NaN       ③ 보통   ⑤ 매우 만족
# 3          ⑤ 매우 만족  ...   ⑤ 매우 만족   ⑤ 매우 만족   ⑤ 매우 만족    ⑤ 매우 만족   ⑤ 매우 만족
# 4             ④ 만족  ...       NaN       NaN      ④ 만족       ③ 보통      ④ 만족
# ...            ...  ...       ...       ...       ...        ...       ...
# 64952     ④ 대체로 만족  ...   ⑤ 매우 만족  ④ 대체로 만족  ④ 대체로 만족   ④ 대체로 만족   ⑤ 매우 만족
# 64953      ⑤ 매우 만족  ...  ④ 대체로 만족   ⑤ 매우 만족   ⑤ 매우 만족    ⑤ 매우 만족   ⑤ 매우 만족
# 64954      ⑤ 매우 만족  ...   ⑤ 매우 만족  ④ 대체로 만족  ④ 대체로 만족    ⑤ 매우 만족   ⑤ 매우 만족
# 64955      ⑤ 매우 만족  ...   ⑤ 매우 만족   ⑤ 매우 만족   ⑤ 매우 만족    ⑤ 매우 만족   ⑤ 매우 만족
# 64956      ⑤ 매우 만족  ...  ④ 대체로 만족   ⑤ 매우 만족   ⑤ 매우 만족  ② 대체로 불만족  ④ 대체로 만족
#
#         budget accommodation transport navigation  year
# 0      ⑤ 매우 만족       ⑤ 매우 만족   ⑤ 매우 만족    ⑤ 매우 만족  2024
# 1         ④ 만족          ④ 만족      ④ 만족       ④ 만족  2024
# 2      ⑤ 매우 만족       ⑤ 매우 만족   ⑤ 매우 만족       ③ 보통  2024
# 3      ⑤ 매우 만족       ⑤ 매우 만족   ⑤ 매우 만족    ⑤ 매우 만족  2024
# 4         ④ 만족          ④ 만족      ④ 만족       ③ 보통  2024
# ...        ...           ...       ...        ...   ...
# 64952  ⑤ 매우 만족       ⑤ 매우 만족  ④ 대체로 만족    ⑤ 매우 만족  2018
# 64953  ⑤ 매우 만족      ④ 대체로 만족   ⑤ 매우 만족   ④ 대체로 만족  2018
# 64954  ⑤ 매우 만족       ⑤ 매우 만족  ④ 대체로 만족    ⓞ 해당 없음  2018
# 64955  ⑤ 매우 만족          ③ 보통   ⑤ 매우 만족    ⑤ 매우 만족  2018
# 64956  ⑤ 매우 만족          ③ 보통  ④ 대체로 만족   ④ 대체로 만족  2018
#
# [64957 rows x 37 columns]

# %%
# 연도별 최초방문/재방문비율
revisit_df = total_df[['year', 'num_visits']].copy()
revisit_df['num_visits_int'] = revisit_df['num_visits'].str.extract(r'(\d+)')

total_per_year = revisit_df.groupby('year').size()
once_per_year = revisit_df[revisit_df['num_visits_int'] == '1'].groupby('year').size()

# 비율 계산
revisit_df_final = pd.DataFrame({
    'year': total_per_year.index,
    'total': total_per_year.values,
    'first_visit': once_per_year.reindex(total_per_year.index, fill_value=0).values
})
revisit_df_final['first_visit_rate'] = np.round((revisit_df_final['first_visit'] / revisit_df_final['total']) * 100, 2)
revisit_df_final['revisit_rate'] = np.round(100 - revisit_df_final['first_visit_rate'], 2)
revisit_df_final
# Out:
#    year  total  first_visit  first_visit_rate  revisit_rate
# 0  2018  16469         7773             47.20         52.80
# 1  2019  16076         7268             45.21         54.79
# 2  2023  16196         7900             48.78         51.22
# 3  2024  16216         7778             47.96         52.04

# %%
# 연도별 평균 숙박일자, 체류일자
duration_df = total_df[['stay_duration', 'total_duration', 'year']].copy()
duration_df = duration_df[
    duration_df['stay_duration'].between(0, 60) &
    duration_df['total_duration'].between(0, 60)
]
np.round(duration_df.groupby('year').mean(), 4)
# Out:
#       stay_duration  total_duration
# year
# 2018         6.9271          7.9477
# 2019         6.3307          7.3371
# 2023         7.7112          8.7112
# 2024         6.6371          7.6371

# %% [markdown]
# # 최종데이터 전처리

# %%
# 데이터 전처리
import re
from pandas.api.types import CategoricalDtype
import warnings
warnings.filterwarnings('ignore')

# 데이터 숫자로 변환하기
output_df = total_df.copy()
for col in ['month', 'quarter', 'num_visits']:
    output_df[col] = output_df[col].str.extract(r'(\d+)').astype("Int64")

# 공백 제거
for col in output_df.columns:
    if output_df[col].dtype == 'object' or output_df[col].dtype == 'category':
        output_df[col] = output_df[col].str.replace(r'[\s]+', '', regex=True)

# 국적
output_df['country'] = output_df['country'].str.replace('전체', '')
country_super_group = {
    '중국': '동아시아',
    '일본': '동아시아',
    '대만': '동아시아',
    '홍콩': '동아시아',
    '몽골': '동아시아',
    '태국': '동남아시아',
    '베트남': '동남아시아',
    '말레이시아': '동남아시아',
    '싱가포르': '동남아시아',
    '필리핀': '동남아시아',
    '인도네시아': '동남아시아',
    '인도': '중동 및 인도',
    '중동': '중동 및 인도',
    '미국': '영어권',
    '캐나다': '영어권',
    '호주': '영어권',
    '영국': '영어권',
    '프랑스': '유럽',
    '독일': '유럽',
    '러시아': '유럽',
    '기타': '기타'
}

country_mapping = {
    '동아시아': 1,
    '동남아시아': 2,
    '중동 및 인도': 3,
    '영어권': 4,
    '유럽': 5,
    '기타': 99}
output_df['country'] = output_df['country'].replace(country_super_group).replace(country_mapping).astype('category')

# 연령
age_mapping = {'15-20세': 1, '15-19세': 1, '10대' : 1,
               '21-30세': 2, '20대': 2, 
               '31-40세': 3, '30대': 3, 
               '41-50세': 4, '40대': 4, 
               '51-60세': 5, '50대': 5, 
               '61세이상': 6, '60대이상': 6}
output_df['age'] = output_df['age'].replace(age_mapping)
age_order = CategoricalDtype(categories=[1, 2, 3, 4, 5, 6], ordered=True)
output_df['age'] = output_df['age'].astype(age_order)

# 성별
output_df['gender'] = output_df['gender'].replace({'남성': 1, '여성': 2}).astype('category')

# 여행 유형
activity_mapping = {
    'K-POP/한류스타관련팬미팅,촬영지등경험': 1,
    'K-POP/한류스타관련공연장및드라마/영화촬영지방문': 1,
    '연극,뮤지컬,발레등공연관람': 1,
    '고궁/역사유적지방문': 2,
    '박물관,전시관관람': 2,
    '역사/문화유적탐방': 2,
    '역사/문화유적/전통문화체험': 2,
    '자연풍경감상': 2,
    '자연경관감상': 2,
    '전통문화체험(한복체험,태권도,한국음식만들기등)': 2,
    '템플스테이태권도등한국전통문화체험': 2,
    '지역축제참여': 2,
    '음식/미식탐방': 3,
    '식도락(음식/미식)관광': 3,
    '쇼핑': 4,
    '레저및스포츠활동': 5,
    '스포츠/레포츠관람(야구,축구,농구등)': 5,
    '스포츠/레포츠참가(스키,수영,골프,캠핑,등반,자전거,래프팅등)': 5,
    '뷰티/미용관광(마사지샵,헤어샵,네일케어등방문)': 6,
    '치료및미용서비스': 6,
    '치료및미용서비스체험': 6,
    '치료/건강검진(피부과,성형외과,내외과입원,수술등)': 6,
    '휴양/휴식(웰니스)': 6,
    '휴가시간': 6,
    '유흥(나이트라이프활동및카지노)': 7,
    '유흥/놀이시설': 7,
    '유흥/놀이시설체험': 7,
    '오락(놀이공원및테마파크방문등': 7,
    '패션,유행등세련된현대문화': 8,
    '패션,유행등세련된현대문화체험': 8,
    '친구,친지방문': 99,
    '경제적인여행비용': 99,
    '숙박/교통등관광편리성및안전성': 99,
    '자국과의이동거리': 99,
    '기후/뚜렷한사계절': 99,
    '기타': 99
}
output_df['planned_activity'] = output_df['planned_activity'].replace(activity_mapping).astype('category')

# 방문목적
purpose_mapping = {
    '여가/위락/휴식': 1,
    '사업또는전문활동': 2,
    '사업/전문활동': 2,
    '친구/친지방문': 3,
    '교육': 4,
    '종교및순례': 5,
    '기타': 99
}
output_df['visit_purpose'] = output_df['visit_purpose'].replace(purpose_mapping).astype('category')

# 여행 유형
travel_type_mapping = {
    '개별여행': 1,
    '단체여행': 2,
    'Air-telTour': 3,
    'AIR-TEL': 3
}
output_df['travel_type'] = output_df['travel_type'].replace(travel_type_mapping).astype('category')

# 만족도
satisfaction_mapping = {
    '⑤매우만족': 5,
    '④만족': 4,
    '④대체로만족': 4,
    '③보통': 3,
    '②불만족': 2,
    '②대체로불만족': 2,
    '①매우불만족': 1,
    'ⓞ해당없음' : pd.NA
}
output_df['satisfaction'] = output_df['satisfaction'].replace(satisfaction_mapping)

# 세부 만족도
cols = ['food', 'landscape', 'heritage', 'language', 'safety', 
        'budget', 'accommodation', 'transport', 'navigation']
for col in cols:
    output_df[col] = output_df[col].map(satisfaction_mapping).astype('Int64')

# 재방문의도, 추천의도
revisit_recommend_intent_mapping = {
    '⑤매우그렇다': 5,
    '④대체로그렇다': 4,
    '③보통': 3,
    '②별로그렇지않다': 2,
    '①전혀그렇지않다': 1
}
output_df['revisit_intent'] = output_df['revisit_intent'].replace(revisit_recommend_intent_mapping)
output_df['recommend_intent'] = output_df['recommend_intent'].replace(revisit_recommend_intent_mapping)

# 지역 방문 여부
output_df[['seoul', 'gyeonggi', 'incheon', 'gangwon', 'chungcheong', 'gyeongsang', 'jeolla', 'jeju']] = output_df[['seoul', 'gyeonggi', 'incheon', 'gangwon', 'chungcheong', 'gyeongsang', 'jeolla', 'jeju']].notna().astype(int)

# %%
# 파생변수
# 재방문여부
output_df['revisit_indicator'] = output_df['num_visits'].apply(lambda x : 0 if int(x) == 1 else 1)

# 지방 방문여부
output_df['temp_flag'] = output_df[['seoul', 'gyeonggi', 'incheon', 'gangwon', 'chungcheong', 'gyeongsang', 'jeolla', 'jeju']].sum(axis=1)

cond1 = (output_df['seoul'] == 1) & (output_df['temp_flag'] == 1)
cond2 = (output_df['seoul'] == 1) & (output_df['temp_flag'] > 1)
output_df['visit_local_indicator'] = 2 # 지방만 방문
output_df.loc[cond1, 'visit_local_indicator'] = 0 # 서울만 방문
output_df.loc[cond2, 'visit_local_indicator'] = 1 # 서울+지방 방문
output_df['visit_local_indicator'] = output_df['visit_local_indicator'].astype('category')
output_df.drop('temp_flag', axis=1, inplace=True)

# 총 여행 지출액 대비 세부 항목의 비중
output_df['accommodation_percent'] = output_df['accommodation_cost'] / output_df['total_expense']
output_df['food_percent'] = output_df['food_cost'] / output_df['total_expense']
output_df['shopping_percent'] = output_df['shopping_cost'] / output_df['total_expense']

# %%
# 데이터 필터링
# 60일 초과 체류인원 삭제
output_df = output_df[output_df['stay_duration'].between(0, 60)]

# 방문목적 여행만 + 방문유형 개별여행만
output_df = output_df[(output_df['visit_purpose'] == 1) & (output_df['travel_type'] == 1)]

# %%
output_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32064 entries, 0 to 64955
# Data columns (total 42 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     32064 non-null  float64
#  1   month                  32064 non-null  Int64
#  2   quarter                32064 non-null  Int64
#  3   country                32064 non-null  category
#  4   gender                 32064 non-null  category
#  5   age                    32064 non-null  category
#  6   visit_purpose          32064 non-null  category
#  7   num_visits             32064 non-null  Int64
#  8   travel_type            32064 non-null  category
#  9   satisfaction           32064 non-null  int64
#  10  revisit_intent         32064 non-null  int64
#  11  recommend_intent       32064 non-null  int64
#  12  seoul                  32064 non-null  int32
#  13  gyeonggi               32064 non-null  int32
#  14  incheon                32064 non-null  int32
#  15  gangwon                32064 non-null  int32
#  16  chungcheong            32064 non-null  int32
#  17  gyeongsang             32064 non-null  int32
#  18  jeolla                 32064 non-null  int32
#  19  jeju                   32064 non-null  int32
#  20  stay_duration          32064 non-null  float64
#  21  total_duration         32064 non-null  float64
#  22  planned_activity       32064 non-null  category
#  23  total_expense          32064 non-null  float64
#  24  accommodation_cost     32064 non-null  float64
#  25  food_cost              32064 non-null  float64
#  26  shopping_cost          32064 non-null  float64
#  27  food                   28561 non-null  Int64
#  28  landscape              25756 non-null  Int64
#  29  heritage               22243 non-null  Int64
#  30  language               32027 non-null  Int64
#  31  safety                 31987 non-null  Int64
#  32  budget                 31980 non-null  Int64
#  33  accommodation          32017 non-null  Int64
#  34  transport              32022 non-null  Int64
#  35  navigation             31285 non-null  Int64
#  36  year                   32064 non-null  int64
#  37  revisit_indicator      32064 non-null  int64
#  38  visit_local_indicator  32064 non-null  category
#  39  accommodation_percent  32064 non-null  float64
#  40  food_percent           32064 non-null  float64
#  41  shopping_percent       32064 non-null  float64
# dtypes: Int64(12), category(7), float64(10), int32(8), int64(5)
# memory usage: 8.4 MB

# %%
col_names_dict = {
    'ID': '응답자 ID',
    'year': '조사연도',
    'month': '방한월',
    'quarter': '방한분기',
    'country': '국적',
    'gender': '성별',
    'age': '연령대',
    'visit_purpose': '방한목적',
    'num_visits': '방한횟수',
    'revisit_indicator': '재방문여부',
    'travel_type': '여행형태',
    'satisfaction': '전반적 만족도',
    'revisit_intent': '재방문의사',
    'recommend_intent': '추천의향',
    'visit_local_indicator': '지방 방문 여부',
    'seoul': '서울 방문 여부',
    'gyeonggi': '경기 방문 여부',
    'incheon': '인천 방문 여부',
    'gangwon': '강원 방문 여부',
    'chungcheong': '충청 방문 여부',
    'gyeongsang': '경상 방문 여부',
    'jeolla': '전라 방문 여부',
    'jeju': '제주 방문 여부',
    'planned_activity': '쇼핑비',
    'stay_duration': '한국 체류일수',
    'total_duration': '총 여행일수',
    'total_expense': '총 지출액',
    'accommodation_cost': '숙박비',
    'food_cost': '음식비',
    'shopping_cost': '쇼핑비',
    'accommodation_percent': '총 지출액 대비 숙박비',
    'food_percent': '총 지출액 대비 음식비',
    'shopping_percent': '총 지출액 대비 쇼핑비',
    'food': '식도락 만족도',
    'landscape': '자연경관 만족도',
    'heritage': '역사유적지 만족도',
    'language': '언어소통 만족도',
    'safety': '치안 만족도',
    'budget': '여행경비 만족도',
    'accommodation': '숙박시설 만족도',
    'transport': '대중교통 만족도',
    'navigation': '길찾기 용이성 만족도'
}

# %%
ordered_cols = list(col_names_dict.keys())
output_df = output_df[ordered_cols]
output_df.to_csv('./관광데이터.csv', header=True, encoding='cp949')
# output_df.rename(columns=col_names_dict)

# %%
# 가설 1. 한국 재방문비율은 COVID-19 이전과 비교하여 유의미한 차이가 있을 것이다.
from scipy.stats import chi2_contingency
revisit_df = output_df[['year', 'revisit_indicator']].copy()
revisit_df['covid_indicator'] = output_df['year'].apply(lambda x : 1 if x > 2020 else 0)
contingency = pd.crosstab(revisit_df['covid_indicator'], revisit_df['revisit_indicator'])

# 카이제곱 검정
chi2, p, df, expected = chi2_contingency(contingency)

# 결과 출력
print(f"카이제곱 통계량:, {chi2:.3f}")
print(f"p값:, {p:.3f}")
print(f"자유도:, {df}")

# 행 기준 비율표 (소수점 → 퍼센트 변환)
percent_table = pd.crosstab(revisit_df['covid_indicator'], revisit_df['revisit_indicator'], normalize='index') * 100
percent_table = percent_table.round(1)
combined = contingency.astype(str) + " (" + percent_table.astype(str) + "%)"
print(f"관측빈도:\n {combined}")
# Out:
# 카이제곱 통계량:, 85.460
# p값:, 0.000
# 자유도:, 1
# 관측빈도:
#  revisit_indicator             0             1
# covid_indicator
# 0                  7872 (47.7%)  8616 (52.3%)
# 1                  8242 (52.9%)  7334 (47.1%)

# %%
# 가설 2. 한국 체류기간은 COVID-19 이전과 비교하여 유의미한 차이가 있을 것이다.
from scipy.stats import ttest_ind, levene
stay_df = output_df[['year', 'stay_duration']].copy()
stay_df['covid_indicator'] = stay_df['year'].apply(lambda x : 1 if x > 2020 else 0)
pre = stay_df[stay_df['covid_indicator'] == 0]['stay_duration']
post = stay_df[stay_df['covid_indicator'] == 1]['stay_duration']

# Levene 등분산성 검정
stat, p = levene(pre, post)

print(f"Levene 등분산성 검정 통계량:, {stat:.3f}")
print(f"p값:, {p:.3f}")

# 독립표본 t 검정
t_stat, p = ttest_ind(pre, post, equal_var=False)

# 결과 출력
print(f"t-통계량:, {t_stat:.3f}")
print(f"p값:, {p:.3f}")
print(f"집단 별 평균\npre : {np.mean(pre):.3f} \npost : {np.mean(post):.3f} \n")
# Out:
# Levene 등분산성 검정 통계량:, 50.742
# p값:, 0.000
# t-통계량:, 1.937
# p값:, 0.053
# 집단 별 평균
# pre : 6.784
# post : 6.635

# %%
# 가설 3. 서울만 여행한 사람보다 서울 근교+지방도 함께 여행한 사람이 여행 만족도가 높을 것이다.
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# 분석 대상 변수들
cols = ['satisfaction', 'revisit_intent', 'recommend_intent']

# 분석용 데이터프레임 준비
anova_df = output_df[['visit_local_indicator'] + cols].copy()

# ANOVA 결과 저장용 딕셔너리
anova_results = {}

# ANOVA 반복 수행
for col in cols:
    formula = f'{col} ~ C(visit_local_indicator)'
    model = ols(formula, data=anova_df).fit()
    anova_table = sm.stats.anova_lm(model, typ=2)
    anova_results[col] = anova_table

# ANOVA 결과 출력
for col, result in anova_results.items():
    print(f"\n[{col}에 대한 ANOVA 결과]")
    print(result)

# 집단별 평균 출력
group_summary = (
    output_df
    .groupby('visit_local_indicator')
    .agg(
        count=('visit_local_indicator', 'size'), 
        satisfaction_mean=('satisfaction', 'mean'),
        revisit_intent_mean=('revisit_intent', 'mean'),
        recommend_intent_mean=('recommend_intent', 'mean')
    )
    .round(4)
)
print("\n[집단별 평균 요약]")
print(group_summary)

# Tukey HSD 사후검정
for col in cols:
    print(f"\n[{col}에 대한 Tukey HSD 결과]")
    tukey = pairwise_tukeyhsd(endog=anova_df[col],
                              groups=anova_df['visit_local_indicator'],
                              alpha=0.05)
    print(tukey.summary())
# Out:
# [satisfaction에 대한 ANOVA 결과]
#                                 sum_sq       df          F        PR(>F)
# C(visit_local_indicator)    148.032434      2.0  206.90242  5.228286e-90
# Residual                  11469.338699  32061.0        NaN           NaN
#
# [revisit_intent에 대한 ANOVA 결과]
#                                 sum_sq       df          F        PR(>F)
# C(visit_local_indicator)     94.213037      2.0  82.873052  1.263001e-36
# Residual                  18224.043418  32061.0        NaN           NaN
#
# [recommend_intent에 대한 ANOVA 결과]
#                                 sum_sq       df           F         PR(>F)
# C(visit_local_indicator)    245.435806      2.0  314.148079  7.706192e-136
# Residual                  12524.216889  32061.0         NaN            NaN
#
# [집단별 평균 요약]
#                        count  satisfaction_mean  revisit_intent_mean  \
# visit_local_indicator
# 0                      16993             4.5174               4.4373
# 1                      10829             4.5506               4.3627
# 2                       4242             4.3347               4.2834
#
#                        recommend_intent_mean
# visit_local_indicator
# 0                                     4.5237
# 1                                     4.5912
# 2                                     4.3081
#
# [satisfaction에 대한 Tukey HSD 결과]
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj  lower   upper  reject
# ---------------------------------------------------
#      0      1   0.0332   0.0  0.0159  0.0504   True
#      0      2  -0.1826   0.0 -0.2067 -0.1586   True
#      1      2  -0.2158   0.0 -0.2412 -0.1904   True
# ---------------------------------------------------
#
# [revisit_intent에 대한 Tukey HSD 결과]
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj  lower   upper  reject
# ---------------------------------------------------
#      0      1  -0.0746   0.0 -0.0963 -0.0528   True
#      0      2  -0.1539   0.0 -0.1843 -0.1236   True
#      1      2  -0.0794   0.0 -0.1114 -0.0474   True
# ---------------------------------------------------
#
# [recommend_intent에 대한 Tukey HSD 결과]
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj  lower   upper  reject
# ---------------------------------------------------
#      0      1   0.0675   0.0  0.0495  0.0855   True
#      0      2  -0.2156   0.0 -0.2407 -0.1904   True
#      1      2  -0.2831   0.0 -0.3096 -0.2565   True
# ---------------------------------------------------

# %%
# 가설 3-2. 서울만 여행한 사람보다 서울 근교+지방도 함께 여행한 사람이 tp여행 만족도가 높을 것이다.
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# 분석 대상 변수들
cols = ['food', 'landscape', 'heritage', 'language', 'safety', 
        'budget', 'accommodation', 'transport', 'navigation']

# 분석용 데이터프레임
analysis_df = output_df[['visit_local_indicator'] + cols].copy()

# 반복 수행: 각 세부 만족도 항목에 대해 ANOVA, 집단별 평균, Tukey HSD 출력
for col in cols:
    print(f"[{col}에 대한 분석]")

    # 변수별 결측값 제거
    anova_df = analysis_df[['visit_local_indicator'] + [col]].dropna().copy()

    # ANOVA
    formula = f'{col} ~ C(visit_local_indicator)'
    model = ols(formula, data=anova_df).fit()
    anova_table = sm.stats.anova_lm(model, typ=2)
    print("\n[ANOVA 결과]")
    print(anova_table)

    # 집단별 평균 및 표준편차
    group_summary = (
        anova_df.groupby('visit_local_indicator')[col]
        .agg(['count', 'mean', 'std'])
        .round(4)
        .rename(columns={'mean': 'mean', 'std': 'std'})
    )
    print("\n[집단별 평균 및 표준편차]")
    print(group_summary)

    # Tukey HSD 사후검정
    tukey = pairwise_tukeyhsd(endog=anova_df[col],
                              groups=anova_df['visit_local_indicator'],
                              alpha=0.05)
    print("\n[Tukey HSD 결과]")
    print(tukey.summary())
# Out:
# [food에 대한 분석]
#
# [ANOVA 결과]
#                                 sum_sq       df          F        PR(>F)
# C(visit_local_indicator)     88.185904      2.0  95.799513  3.417796e-42
# Residual                  13144.185021  28558.0        NaN           NaN
#
# [집단별 평균 및 표준편차]
#                        count    mean     std
# visit_local_indicator
# 0                      15225  4.4826  0.6701
# 1                       9420  4.4722  0.6835
# 2                       3916  4.3177  0.6983
#
# [Tukey HSD 결과]
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      0      1  -0.0104 0.4688 -0.0313  0.0104  False
#      0      2   -0.165    0.0 -0.1934 -0.1365   True
#      1      2  -0.1545    0.0 -0.1847 -0.1243   True
# ----------------------------------------------------
# [landscape에 대한 분석]
#
# [ANOVA 결과]
#                                 sum_sq       df          F        PR(>F)
# C(visit_local_indicator)    109.597697      2.0  130.05008  6.357411e-57
# Residual                  10851.471530  25753.0        NaN           NaN
#
# [집단별 평균 및 표준편차]
#                        count    mean     std
# visit_local_indicator
# 0                      12354  4.4779  0.6697
# 1                       9555  4.5882  0.6098
# 2                       3847  4.4099  0.6762
#
# [Tukey HSD 결과]
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj  lower   upper  reject
# ---------------------------------------------------
#      0      1   0.1103   0.0  0.0895   0.131   True
#      0      2   -0.068   0.0 -0.0961 -0.0399   True
#      1      2  -0.1782   0.0 -0.2073 -0.1492   True
# ---------------------------------------------------
# [heritage에 대한 분석]
#
# [ANOVA 결과]
#                                sum_sq       df           F        PR(>F)
# C(visit_local_indicator)   150.834664      2.0  170.525304  3.190832e-74
# Residual                  9835.968195  22240.0         NaN           NaN
#
# [집단별 평균 및 표준편차]
#                        count    mean     std
# visit_local_indicator
# 0                      11134  4.4585  0.6808
# 1                       8322  4.5609  0.6288
# 2                       2787  4.2989  0.7053
#
# [Tukey HSD 결과]
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj  lower   upper  reject
# ---------------------------------------------------
#      0      1   0.1024   0.0  0.0798   0.125   True
#      0      2  -0.1596   0.0 -0.1926 -0.1266   True
#      1      2   -0.262   0.0 -0.2961 -0.2279   True
# ---------------------------------------------------
# [language에 대한 분석]
#
# [ANOVA 결과]
#                                 sum_sq       df          F        PR(>F)
# C(visit_local_indicator)     41.401113      2.0  26.075487  4.839168e-12
# Residual                  25422.904192  32024.0        NaN           NaN
#
# [집단별 평균 및 표준편차]
#                        count    mean     std
# visit_local_indicator
# 0                      16970  4.1962  0.8726
# 1                      10817   4.149  0.9308
# 2                       4240  4.0927  0.8594
#
# [Tukey HSD 결과]
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      0      1  -0.0472    0.0 -0.0729 -0.0215   True
#      0      2  -0.1035    0.0 -0.1394 -0.0677   True
#      1      2  -0.0563 0.0014 -0.0942 -0.0185   True
# ----------------------------------------------------
# [safety에 대한 분석]
#
# [ANOVA 결과]
#                                 sum_sq       df          F        PR(>F)
# C(visit_local_indicator)     54.093433      2.0  48.961331  5.872841e-22
# Residual                  17668.273341  31984.0        NaN           NaN
#
# [집단별 평균 및 표준편차]
#                        count    mean     std
# visit_local_indicator
# 0                      16954  4.3928  0.7417
# 1                      10807   4.415  0.7425
# 2                       4226  4.2837  0.7513
#
# [Tukey HSD 결과]
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      0      1   0.0222 0.0406  0.0007  0.0436   True
#      0      2  -0.1091    0.0 -0.1391 -0.0792   True
#      1      2  -0.1313    0.0 -0.1629 -0.0997   True
# ----------------------------------------------------
# [budget에 대한 분석]
#
# [ANOVA 결과]
#                                 sum_sq       df          F        PR(>F)
# C(visit_local_indicator)     71.942935      2.0  50.597288  1.149671e-22
# Residual                  22733.622137  31977.0        NaN           NaN
#
# [집단별 평균 및 표준편차]
#                        count    mean     std
# visit_local_indicator
# 0                      16945  4.1744   0.832
# 1                      10808  4.0953   0.865
# 2                       4227  4.0523  0.8309
#
# [Tukey HSD 결과]
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      0      1  -0.0791    0.0 -0.1035 -0.0548   True
#      0      2  -0.1222    0.0 -0.1561 -0.0882   True
#      1      2   -0.043 0.0136 -0.0789 -0.0072   True
# ----------------------------------------------------
# [accommodation에 대한 분석]
#
# [ANOVA 결과]
#                                 sum_sq       df          F        PR(>F)
# C(visit_local_indicator)     60.131761      2.0  60.044665  9.369594e-27
# Residual                  16030.218552  32014.0        NaN           NaN
#
# [집단별 평균 및 표준편차]
#                        count    mean     std
# visit_local_indicator
# 0                      16963  4.4196  0.7107
# 1                      10826  4.4267  0.7008
# 2                       4228  4.2947  0.7127
#
# [Tukey HSD 결과]
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      0      1    0.007 0.6977 -0.0134  0.0274  False
#      0      2  -0.1249    0.0 -0.1534 -0.0964   True
#      1      2   -0.132    0.0  -0.162 -0.1019   True
# ----------------------------------------------------
# [transport에 대한 분석]
#
# [ANOVA 결과]
#                                 sum_sq       df          F        PR(>F)
# C(visit_local_indicator)     74.919169      2.0  65.108225  6.042257e-29
# Residual                  18421.918911  32019.0        NaN           NaN
#
# [집단별 평균 및 표준편차]
#                        count    mean     std
# visit_local_indicator
# 0                      16967  4.3824  0.7582
# 1                      10825  4.4009  0.7598
# 2                       4230  4.2489  0.7566
#
# [Tukey HSD 결과]
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      0      1   0.0185 0.1155 -0.0033  0.0404  False
#      0      2  -0.1335    0.0  -0.164 -0.1029   True
#      1      2   -0.152    0.0 -0.1842 -0.1198   True
# ----------------------------------------------------
# [navigation에 대한 분석]
#
# [ANOVA 결과]
#                                 sum_sq       df          F    PR(>F)
# C(visit_local_indicator)     16.790982      2.0  13.263755  0.000002
# Residual                  19800.407675  31282.0        NaN       NaN
#
# [집단별 평균 및 표준편차]
#                        count    mean     std
# visit_local_indicator
# 0                      16503  4.2778  0.7977
# 1                      10627  4.2574  0.8046
# 2                       4155  4.2072  0.7634
#
# [Tukey HSD 결과]
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      0      1  -0.0204 0.0979 -0.0436  0.0028  False
#      0      2  -0.0705    0.0 -0.1029 -0.0382   True
#      1      2  -0.0501 0.0017 -0.0843  -0.016   True
# ----------------------------------------------------

# %% [markdown]
# # 클러스터링

# %%
output_df.columns
# Out:
# Index(['ID', 'year', 'month', 'quarter', 'country', 'gender', 'age',
#        'visit_purpose', 'num_visits', 'revisit_indicator', 'travel_type',
#        'satisfaction', 'revisit_intent', 'recommend_intent',
#        'visit_local_indicator', 'seoul', 'gyeonggi', 'incheon', 'gangwon',
#        'chungcheong', 'gyeongsang', 'jeolla', 'jeju', 'planned_activity',
#        'stay_duration', 'total_duration', 'total_expense',
#        'accommodation_cost', 'food_cost', 'shopping_cost',
#        'accommodation_percent', 'food_percent', 'shopping_percent', 'food',
#        'landscape', 'heritage', 'language', 'safety', 'budget',
#        'accommodation', 'transport', 'navigation'],
#       dtype='object')

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler, MinMaxScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.decomposition import PCA
from tqdm import tqdm

# 변수 구분
categorical_cols = ['country', 'gender', 'age',
                    'revisit_indicator', 'visit_local_indicator', 'planned_activity']
for col in categorical_cols:
    output_df[col] = output_df[col].astype(str)

numerical_cols = [
    'stay_duration', 'accommodation_percent', 'food_percent', 'shopping_percent', 'food',
    'landscape', 'heritage', 'language', 'safety', 'budget',
    'accommodation', 'transport', 'navigation'
]

# 전처리기 정의
preprocessor = ColumnTransformer(transformers=[
    ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_cols),
    ('num', MinMaxScaler(), numerical_cols)
])

# 결측값 제거
output_df_clean = output_df.dropna(subset=categorical_cols + numerical_cols)
X_preprocessed = preprocessor.fit_transform(output_df_clean)

# 실험 범위 정의
pca_dims = [3, 4, 5]
k_values = [3, 4, 5, 6, 7, 8, 9, 10]

results = []

# 반복 실험
for n_components in tqdm(pca_dims, desc="PCA 차원별 반복"):
    X_reduced = PCA(n_components=n_components, random_state=42).fit_transform(X_preprocessed)

    for k in k_values:
        model = KMeans(n_clusters=k, random_state=42)
        labels = model.fit_predict(X_reduced)
        score = silhouette_score(X_reduced, labels)
        results.append({
            'n_components': n_components,
            'n_clusters': k,
            'silhouette_score': score
        })

# 결과 정리
result_df = pd.DataFrame(results)
result_df = result_df.sort_values(by='silhouette_score', ascending=False)

# 출력
import seaborn as sns
import matplotlib.pyplot as plt

print(result_df.head())

# 시각화
pivot_table = result_df.pivot(index='n_components', columns='n_clusters', values='silhouette_score')

plt.figure(figsize=(10, 6))
sns.heatmap(pivot_table, annot=True, fmt=".3f", cmap='YlGnBu')
plt.title('Silhouette Score by PCA Dimensions and Number of Clusters')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('PCA Components')
plt.tight_layout()
plt.show()
# Out:
# PCA 차원별 반복: 100%|██████████| 3/3 [02:17<00:00, 45.89s/it]
#    n_components  n_clusters  silhouette_score
# 4             3           7          0.545229
# 5             3           8          0.516674
# 7             3          10          0.511917
# 6             3           9          0.504785
# 3             3           6          0.501446

# %%
from scipy.stats import skew, kurtosis

# 기술통계 계산
desc = output_df_clean[numerical_cols].describe().T 

# 왜도와 첨도 계산
desc['skewness'] = output_df_clean[numerical_cols].skew()
desc['kurtosis'] = output_df_clean[numerical_cols].kurt()
desc = desc[['mean', 'std', 'min', 'max', 'skewness', 'kurtosis']]
desc
# Out:
#                            mean       std  min   max  skewness  kurtosis
# stay_duration           7.00568  7.562927  0.0  60.0   3.99856   20.2539
# accommodation_percent  0.243532  0.158499  0.0   1.0  0.772245  0.730894
# food_percent           0.356958  0.227107  0.0   1.0   0.58952 -0.391054
# shopping_percent       0.195001  0.122942  0.0   1.0  1.419076  4.081657
# food                   4.407488    0.7076  1.0   5.0 -1.088609  1.205084
# landscape              4.459437  0.673647  1.0   5.0 -1.073285  0.968388
# heritage               4.455874  0.675337  1.0   5.0 -1.065933  0.945014
# language               4.029744  0.926633  1.0   5.0 -0.742478  0.098748
# safety                 4.355383  0.767896  1.0   5.0 -1.152345  1.339546
# budget                 3.983114  0.873935  1.0   5.0  -0.60615  0.086336
# accommodation          4.371237  0.713945  1.0   5.0 -1.017633  1.140154
# transport              4.404544  0.725306  1.0   5.0 -1.217837  1.780578
# navigation             4.251433  0.792601  1.0   5.0 -0.945427  0.820649

# %%
# best PCA 적용
pca = PCA(n_components=3).fit(X_preprocessed)
print("explained_variance_ratio :", pca.explained_variance_ratio_.sum())
X_reduced = pca.fit_transform(X_preprocessed)

# 클러스터링
kmeans = KMeans(n_clusters=7, random_state=42)
output_df_clean['cluster'] = kmeans.fit_predict(X_reduced)

# 평가 (Silhouette Score)
score = silhouette_score(X_reduced, output_df_clean['cluster'])
print(f"Silhouette Score (PCA=5): {score:.4f}")

# 클러스터별 개수 확인
print(output_df_clean['cluster'].value_counts())

# 클러스터별 분석
print("\n[범주형 변수 분포]")
print(output_df_clean.groupby('cluster')[categorical_cols].value_counts().head(10))

print("\n[연속형 변수 평균]")
print(output_df_clean.groupby('cluster')[numerical_cols].mean())

output_df_clean.to_csv('./관광데이터_클러스터.csv', header=True, encoding='cp949')
# Out:
# explained_variance_ratio : 0.3632371775357145
# Silhouette Score (PCA=5): 0.5452
# cluster
# 3    4160
# 2    3111
# 4    2885
# 6    2692
# 5    2412
# 1    2106
# 0    1999
# Name: count, dtype: int64
#
# [범주형 변수 분포]
# cluster  country  gender  age  revisit_indicator  visit_local_indicator  planned_activity
# 0        1        2       2    1                  1                      3.0                 67
#                                                                          4.0                 64
#          2        2       2    1                  1                      4.0                 55
#                                                                          3.0                 54
#          1        2       4    1                  1                      3.0                 51
#                           3    1                  1                      4.0                 47
#                                                   2                      2.0                 47
#          2        2       2    1                  1                      2.0                 43
#                           3    1                  1                      3.0                 41
#          1        2       5    1                  1                      3.0                 39
# Name: count, dtype: int64
#
# [연속형 변수 평균]
#          stay_duration  accommodation_percent  food_percent  shopping_percent  \
# cluster
# 0             9.380690               0.237321      0.346514          0.207689
# 1             5.738367               0.268244      0.321434          0.203837
# 2             5.565734               0.241778      0.357972          0.188503
# 3             4.833894               0.208980      0.473369          0.173014
# 4             7.287695               0.234401      0.386259          0.213682
# 5             9.023632               0.282216      0.252123          0.201188
# 6             9.143388               0.259355      0.273971          0.194593
#
#              food  landscape  heritage  language    safety    budget  \
# cluster
# 0        4.425713   4.464232   4.45973  4.041021  4.358679   3.94097
# 1        4.393162    4.48433  4.482906  4.003324  4.337132  3.959639
# 2        4.415943   4.462552  4.468017  4.064609   4.36162  4.035358
# 3        4.384135    4.34399  4.345433   4.09375  4.286058   4.01875
# 4        4.377123   4.382322  4.380936  3.949047  4.345927  3.919931
# 5        4.426617   4.566335   4.55597  3.973881  4.420398  3.956882
# 6         4.44688   4.598068  4.579123  4.039376  4.419019  4.008544
#
#          accommodation  transport  navigation
# cluster
# 0             4.372686   4.402201    4.258629
# 1             4.361349   4.418329    4.237417
# 2             4.388621   4.403729    4.261331
# 3             4.352885   4.344712    4.246154
# 4             4.336222   4.381976    4.233276
# 5             4.388889   4.475954    4.252488
# 6             4.407875   4.449108    4.272288

# %% [markdown]
# # SY 분석

# %%
output_df_clean.info()

# mean: num_visits, satisfaction, revisit_intent, recommend_intent
#       , total_duration, total_expense, accommodation_cost, food_cost, shopping_cost
#       , accommodation_percent, food_percent, shopping_percent
#       , food, landscape, heritage, language, safety, budget, accomodation, transport, navigation
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19365 entries, 3 to 64955
# Data columns (total 43 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     19365 non-null  float64
#  1   year                   19365 non-null  int64
#  2   month                  19365 non-null  Int64
#  3   quarter                19365 non-null  Int64
#  4   country                19365 non-null  object
#  5   gender                 19365 non-null  object
#  6   age                    19365 non-null  object
#  7   visit_purpose          19365 non-null  category
#  8   num_visits             19365 non-null  Int64
#  9   revisit_indicator      19365 non-null  object
#  10  travel_type            19365 non-null  category
#  11  satisfaction           19365 non-null  int64
#  12  revisit_intent         19365 non-null  int64
#  13  recommend_intent       19365 non-null  int64
#  14  visit_local_indicator  19365 non-null  object
#  15  seoul                  19365 non-null  int32
#  16  gyeonggi               19365 non-null  int32
#  17  incheon                19365 non-null  int32
#  18  gangwon                19365 non-null  int32
#  19  chungcheong            19365 non-null  int32
#  20  gyeongsang             19365 non-null  int32
#  21  jeolla                 19365 non-null  int32
#  22  jeju                   19365 non-null  int32
#  23  planned_activity       19365 non-null  object
#  24  stay_duration          19365 non-null  float64
#  25  total_duration         19365 non-null  float64
#  26  total_expense          19365 non-null  float64
#  27  accommodation_cost     19365 non-null  float64
#  28  food_cost              19365 non-null  float64
#  29  shopping_cost          19365 non-null  float64
#  30  accommodation_percent  19365 non-null  float64
#  31  food_percent           19365 non-null  float64
#  32  shopping_percent       19365 non-null  float64
#  33  food                   19365 non-null  Int64
#  34  landscape              19365 non-null  Int64
#  35  heritage               19365 non-null  Int64
#  36  language               19365 non-null  Int64
#  37  safety                 19365 non-null  Int64
#  38  budget                 19365 non-null  Int64
#  39  accommodation          19365 non-null  Int64
#  40  transport              19365 non-null  Int64
#  41  navigation             19365 non-null  Int64
#  42  cluster                19365 non-null  int32
# dtypes: Int64(12), category(2), float64(10), int32(9), int64(4), object(6)
# memory usage: 5.8+ MB

# %%
output_df_clean_2 = output_df_clean.copy()

# 1. 분석에서 제외할 컬럼과 그룹화할 컬럼 정의
exclude_cols = ['ID', 'year', 'visit_purpose', 'travel_type', 'stay_duration']
mean_cols = [
    'num_visits', 'satisfaction', 'revisit_intent', 'recommend_intent',
    'total_duration', 'total_expense', 'accommodation_cost', 'food_cost', 'shopping_cost',
    'accommodation_percent', 'food_percent', 'shopping_percent',
    'food', 'landscape', 'heritage', 'language', 'safety', 'budget',
    'accommodation', 'transport', 'navigation'
]

groupby_col = 'cluster'

# 2. 분석할 대상 컬럼만 선택
columns_to_analyze = [col for col in output_df_clean_2.columns if col not in exclude_cols + [groupby_col]]

# 3. 매핑 정의 (한글 → 숫자) ← 숫자는 반드시 int 로!!
country_mapping = {'동아시아': 1, '동남아시아': 2, '중동 및 인도': 3, '영어권': 4, '유럽': 5, '기타': 99}
age_mapping = {'10대': 1, '20대': 2, '30대': 3, '40대': 4, '50대': 5, '60대이상': 6}
visit_local_mapping = {'서울': 0, '서울+지방': 1, '지방': 2}
gender_mapping = {'남성': 1, '여성': 2}
planned_activity_mapping = {
    '한류/공연': 1, '문화/역사/자연': 2, '음식/미식': 3, '쇼핑': 4,
    '스포츠/레저': 5, '뷰티/휴식/의료': 6, '유흥/오락': 7, '현대문화': 8, '기타': 99
}

all_mappings = {'country': country_mapping, 'age': age_mapping, 'gender': gender_mapping, 'planned_activity': planned_activity_mapping}
all_reverse_mappings = {col: {v: k for k, v in mapping.items()} for col, mapping in all_mappings.items()}


# 4. 클러스터별 비율 분석 및 출력 시 라벨 변환
print("✅ 최종 출력 라벨만 한글로 변환한 분석 결과:\n")
for column in columns_to_analyze:
    print(f"\n=== Analyzing Column: {column} ===")

    if column in all_reverse_mappings:
        # 1) 매핑 후 범주형 비율 출력
        mapper = all_reverse_mappings[column]
        output_df_clean_2[column] = pd.to_numeric(output_df_clean_2[column], errors='coerce')
        output_df_clean_2[column] = output_df_clean_2[column].map(mapper)

        cluster_groups = output_df_clean_2.groupby(groupby_col)[column]
        for cluster_id, group in cluster_groups:
            print(f"\n[Cluster {cluster_id} - {column} (Mapped Categorical)]")
            value_counts = group.value_counts(normalize=True, dropna=True) * 100
            for value, percent in value_counts.items():
                print(f"  {value}: {percent:.2f}%")

    elif column in mean_cols and column in output_df_clean.columns:
        # 2) 숫자형 평균 출력
        print(f"\n[Cluster-wise Mean of '{column}']")
        mean_by_cluster = output_df_clean.groupby(groupby_col)[column].mean()
        for cluster_id, mean_value in mean_by_cluster.items():
            print(f"  Cluster {cluster_id}: {mean_value:.2f}")

    else:
        # 3) 매핑도 평균도 아니면 원본값으로 비율 출력
        cluster_groups = output_df_clean_2.groupby(groupby_col)[column]
        for cluster_id, group in cluster_groups:
            print(f"\n[Cluster {cluster_id} - {column} (Raw Ratio)]")
            value_counts = group.value_counts(normalize=True, dropna=True) * 100
            for value, percent in value_counts.items():
                print(f"  {value}: {percent:.2f}%")
# Out:
# ✅ 최종 출력 라벨만 한글로 변환한 분석 결과:
#
#
# === Analyzing Column: month ===
#
# [Cluster 0 - month (Raw Ratio)]
#   10: 10.06%
#   2: 9.25%
#   9: 9.25%
#   11: 8.85%
#   12: 8.85%
#   4: 8.40%
#   8: 8.10%
#   6: 7.85%
#   7: 7.80%
#   5: 7.40%
#   3: 7.25%
#   1: 6.90%
#
# [Cluster 1 - month (Raw Ratio)]
#   3: 10.16%
#   4: 9.64%
#   5: 9.35%
#   7: 9.02%
#   8: 8.74%
#   6: 8.26%
#   9: 8.02%
#   1: 7.83%
#   2: 7.69%
#   10: 7.64%
#   11: 7.60%
#   12: 6.03%
#
# [Cluster 2 - month (Raw Ratio)]
#   3: 9.55%
#   5: 9.19%
#   4: 8.84%
#   10: 8.58%
#   6: 8.55%
#   7: 8.52%
#   8: 8.45%
#   11: 8.42%
#   9: 8.33%
#   12: 7.39%
#   1: 7.30%
#   2: 6.88%
#
# [Cluster 3 - month (Raw Ratio)]
#   4: 9.25%
#   9: 8.85%
#   3: 8.80%
#   1: 8.68%
#   11: 8.58%
#   12: 8.56%
#   10: 8.17%
#   6: 8.12%
#   8: 8.08%
#   5: 7.88%
#   7: 7.84%
#   2: 7.19%
#
# [Cluster 4 - month (Raw Ratio)]
#   3: 9.08%
#   9: 8.80%
#   8: 8.77%
#   6: 8.73%
#   4: 8.49%
#   2: 8.46%
#   5: 8.35%
#   10: 8.32%
#   12: 8.11%
#   11: 8.01%
#   7: 7.66%
#   1: 7.21%
#
# [Cluster 5 - month (Raw Ratio)]
#   10: 10.36%
#   9: 9.91%
#   5: 9.58%
#   4: 8.71%
#   11: 8.58%
#   6: 8.13%
#   2: 8.04%
#   7: 7.88%
#   8: 7.59%
#   12: 7.50%
#   3: 7.17%
#   1: 6.55%
#
# [Cluster 6 - month (Raw Ratio)]
#   9: 9.81%
#   10: 9.62%
#   4: 8.99%
#   7: 8.80%
#   6: 8.69%
#   5: 8.51%
#   3: 8.06%
#   11: 8.06%
#   2: 7.80%
#   8: 7.80%
#   12: 7.32%
#   1: 6.54%
#
# === Analyzing Column: quarter ===
#
# [Cluster 0 - quarter (Raw Ratio)]
#   4: 27.76%
#   3: 25.16%
#   2: 23.66%
#   1: 23.41%
#
# [Cluster 1 - quarter (Raw Ratio)]
#   2: 27.26%
#   3: 25.78%
#   1: 25.69%
#   4: 21.27%
#
# [Cluster 2 - quarter (Raw Ratio)]
#   2: 26.58%
#   3: 25.30%
#   4: 24.40%
#   1: 23.72%
#
# [Cluster 3 - quarter (Raw Ratio)]
#   4: 25.31%
#   2: 25.26%
#   3: 24.76%
#   1: 24.66%
#
# [Cluster 4 - quarter (Raw Ratio)]
#   2: 25.58%
#   3: 25.23%
#   1: 24.75%
#   4: 24.44%
#
# [Cluster 5 - quarter (Raw Ratio)]
#   4: 26.45%
#   2: 26.41%
#   3: 25.37%
#   1: 21.77%
#
# [Cluster 6 - quarter (Raw Ratio)]
#   3: 26.41%
#   2: 26.19%
#   4: 25.00%
#   1: 22.40%
#
# === Analyzing Column: country ===
#
# [Cluster 0 - country (Mapped Categorical)]
#   동아시아: 37.17%
#   동남아시아: 36.32%
#   영어권: 12.51%
#   유럽: 9.05%
#   중동 및 인도: 3.20%
#   기타: 1.75%
#
# [Cluster 1 - country (Mapped Categorical)]
#   동아시아: 37.56%
#   영어권: 20.94%
#   동남아시아: 18.28%
#   유럽: 12.30%
#   중동 및 인도: 5.84%
#   기타: 5.08%
#
# [Cluster 2 - country (Mapped Categorical)]
#   동아시아: 46.67%
#   동남아시아: 19.29%
#   영어권: 18.39%
#   유럽: 8.36%
#   중동 및 인도: 4.15%
#   기타: 3.15%
#
# [Cluster 3 - country (Mapped Categorical)]
#   동아시아: 75.19%
#   동남아시아: 14.66%
#   영어권: 5.19%
#   유럽: 2.93%
#   중동 및 인도: 1.42%
#   기타: 0.60%
#
# [Cluster 4 - country (Mapped Categorical)]
#   동아시아: 57.02%
#   동남아시아: 19.45%
#   영어권: 11.68%
#   유럽: 6.90%
#   중동 및 인도: 2.63%
#   기타: 2.32%
#
# [Cluster 5 - country (Mapped Categorical)]
#   동남아시아: 36.65%
#   영어권: 28.11%
#   유럽: 13.60%
#   동아시아: 10.82%
#   중동 및 인도: 5.43%
#   기타: 5.39%
#
# [Cluster 6 - country (Mapped Categorical)]
#   동남아시아: 36.11%
#   영어권: 25.45%
#   동아시아: 14.15%
#   유럽: 13.22%
#   중동 및 인도: 5.72%
#   기타: 5.35%
#
# === Analyzing Column: gender ===
#
# [Cluster 0 - gender (Mapped Categorical)]
#   여성: 100.00%
#
# [Cluster 1 - gender (Mapped Categorical)]
#   남성: 100.00%
#
# [Cluster 2 - gender (Mapped Categorical)]
#   여성: 100.00%
#
# [Cluster 3 - gender (Mapped Categorical)]
#   여성: 100.00%
#
# [Cluster 4 - gender (Mapped Categorical)]
#   남성: 100.00%
#
# [Cluster 5 - gender (Mapped Categorical)]
#   남성: 100.00%
#
# [Cluster 6 - gender (Mapped Categorical)]
#   여성: 100.00%
#
# === Analyzing Column: age ===
#
# [Cluster 0 - age (Mapped Categorical)]
#   20대: 34.67%
#   30대: 24.81%
#   50대: 16.91%
#   40대: 16.81%
#   60대이상: 3.40%
#   10대: 3.40%
#
# [Cluster 1 - age (Mapped Categorical)]
#   20대: 41.98%
#   30대: 24.60%
#   40대: 15.34%
#   50대: 11.97%
#   10대: 3.89%
#   60대이상: 2.23%
#
# [Cluster 2 - age (Mapped Categorical)]
#   20대: 46.51%
#   30대: 21.41%
#   50대: 12.99%
#   40대: 11.60%
#   10대: 5.18%
#   60대이상: 2.31%
#
# [Cluster 3 - age (Mapped Categorical)]
#   20대: 40.41%
#   30대: 24.78%
#   40대: 15.12%
#   50대: 13.15%
#   10대: 3.89%
#   60대이상: 2.64%
#
# [Cluster 4 - age (Mapped Categorical)]
#   30대: 28.77%
#   20대: 27.94%
#   50대: 17.99%
#   40대: 17.78%
#   60대이상: 5.03%
#   10대: 2.50%
#
# [Cluster 5 - age (Mapped Categorical)]
#   20대: 39.68%
#   30대: 27.61%
#   40대: 13.97%
#   50대: 12.44%
#   60대이상: 3.23%
#   10대: 3.07%
#
# [Cluster 6 - age (Mapped Categorical)]
#   20대: 45.36%
#   30대: 22.44%
#   50대: 12.37%
#   40대: 12.26%
#   10대: 4.61%
#   60대이상: 2.97%
#
# === Analyzing Column: num_visits ===
#
# [Cluster-wise Mean of 'num_visits']
#   Cluster 0: 2.91
#   Cluster 1: 1.00
#   Cluster 2: 1.00
#   Cluster 3: 3.15
#   Cluster 4: 3.03
#   Cluster 5: 1.17
#   Cluster 6: 1.00
#
# === Analyzing Column: revisit_indicator ===
#
# [Cluster 0 - revisit_indicator (Raw Ratio)]
#   1: 100.00%
#
# [Cluster 1 - revisit_indicator (Raw Ratio)]
#   0: 100.00%
#
# [Cluster 2 - revisit_indicator (Raw Ratio)]
#   0: 99.81%
#   1: 0.19%
#
# [Cluster 3 - revisit_indicator (Raw Ratio)]
#   1: 100.00%
#
# [Cluster 4 - revisit_indicator (Raw Ratio)]
#   1: 100.00%
#
# [Cluster 5 - revisit_indicator (Raw Ratio)]
#   0: 89.97%
#   1: 10.03%
#
# [Cluster 6 - revisit_indicator (Raw Ratio)]
#   0: 100.00%
#
# === Analyzing Column: satisfaction ===
#
# [Cluster-wise Mean of 'satisfaction']
#   Cluster 0: 4.47
#   Cluster 1: 4.47
#   Cluster 2: 4.44
#   Cluster 3: 4.39
#   Cluster 4: 4.40
#   Cluster 5: 4.51
#   Cluster 6: 4.53
#
# === Analyzing Column: revisit_intent ===
#
# [Cluster-wise Mean of 'revisit_intent']
#   Cluster 0: 4.43
#   Cluster 1: 4.17
#   Cluster 2: 4.24
#   Cluster 3: 4.36
#   Cluster 4: 4.35
#   Cluster 5: 4.21
#   Cluster 6: 4.29
#
# === Analyzing Column: recommend_intent ===
#
# [Cluster-wise Mean of 'recommend_intent']
#   Cluster 0: 4.51
#   Cluster 1: 4.40
#   Cluster 2: 4.38
#   Cluster 3: 4.35
#   Cluster 4: 4.39
#   Cluster 5: 4.53
#   Cluster 6: 4.57
#
# === Analyzing Column: visit_local_indicator ===
#
# [Cluster 0 - visit_local_indicator (Raw Ratio)]
#   1: 85.84%
#   2: 14.16%
#
# [Cluster 1 - visit_local_indicator (Raw Ratio)]
#   0: 85.00%
#   2: 15.00%
#
# [Cluster 2 - visit_local_indicator (Raw Ratio)]
#   0: 86.27%
#   2: 13.73%
#
# [Cluster 3 - visit_local_indicator (Raw Ratio)]
#   0: 85.02%
#   2: 14.98%
#
# [Cluster 4 - visit_local_indicator (Raw Ratio)]
#   0: 52.65%
#   1: 29.43%
#   2: 17.92%
#
# [Cluster 5 - visit_local_indicator (Raw Ratio)]
#   1: 91.58%
#   2: 8.42%
#
# [Cluster 6 - visit_local_indicator (Raw Ratio)]
#   1: 91.23%
#   2: 8.77%
#
# === Analyzing Column: seoul ===
#
# [Cluster 0 - seoul (Raw Ratio)]
#   1: 85.84%
#   0: 14.16%
#
# [Cluster 1 - seoul (Raw Ratio)]
#   1: 85.00%
#   0: 15.00%
#
# [Cluster 2 - seoul (Raw Ratio)]
#   1: 86.27%
#   0: 13.73%
#
# [Cluster 3 - seoul (Raw Ratio)]
#   1: 85.02%
#   0: 14.98%
#
# [Cluster 4 - seoul (Raw Ratio)]
#   1: 82.08%
#   0: 17.92%
#
# [Cluster 5 - seoul (Raw Ratio)]
#   1: 91.58%
#   0: 8.42%
#
# [Cluster 6 - seoul (Raw Ratio)]
#   1: 91.23%
#   0: 8.77%
#
# === Analyzing Column: gyeonggi ===
#
# [Cluster 0 - gyeonggi (Raw Ratio)]
#   0: 69.53%
#   1: 30.47%
#
# [Cluster 1 - gyeonggi (Raw Ratio)]
#   0: 99.53%
#   1: 0.47%
#
# [Cluster 2 - gyeonggi (Raw Ratio)]
#   0: 99.87%
#   1: 0.13%
#
# [Cluster 3 - gyeonggi (Raw Ratio)]
#   0: 99.42%
#   1: 0.58%
#
# [Cluster 4 - gyeonggi (Raw Ratio)]
#   0: 87.83%
#   1: 12.17%
#
# [Cluster 5 - gyeonggi (Raw Ratio)]
#   0: 69.15%
#   1: 30.85%
#
# [Cluster 6 - gyeonggi (Raw Ratio)]
#   0: 70.25%
#   1: 29.75%
#
# === Analyzing Column: incheon ===
#
# [Cluster 0 - incheon (Raw Ratio)]
#   0: 86.14%
#   1: 13.86%
#
# [Cluster 1 - incheon (Raw Ratio)]
#   0: 99.48%
#   1: 0.52%
#
# [Cluster 2 - incheon (Raw Ratio)]
#   0: 99.68%
#   1: 0.32%
#
# [Cluster 3 - incheon (Raw Ratio)]
#   0: 99.76%
#   1: 0.24%
#
# [Cluster 4 - incheon (Raw Ratio)]
#   0: 92.86%
#   1: 7.14%
#
# [Cluster 5 - incheon (Raw Ratio)]
#   0: 86.07%
#   1: 13.93%
#
# [Cluster 6 - incheon (Raw Ratio)]
#   0: 86.37%
#   1: 13.63%
#
# === Analyzing Column: gangwon ===
#
# [Cluster 0 - gangwon (Raw Ratio)]
#   0: 72.84%
#   1: 27.16%
#
# [Cluster 1 - gangwon (Raw Ratio)]
#   0: 99.76%
#   1: 0.24%
#
# [Cluster 2 - gangwon (Raw Ratio)]
#   0: 99.97%
#   1: 0.03%
#
# [Cluster 3 - gangwon (Raw Ratio)]
#   0: 99.78%
#   1: 0.22%
#
# [Cluster 4 - gangwon (Raw Ratio)]
#   0: 90.16%
#   1: 9.84%
#
# [Cluster 5 - gangwon (Raw Ratio)]
#   0: 70.11%
#   1: 29.89%
#
# [Cluster 6 - gangwon (Raw Ratio)]
#   0: 70.88%
#   1: 29.12%
#
# === Analyzing Column: chungcheong ===
#
# [Cluster 0 - chungcheong (Raw Ratio)]
#   0: 94.50%
#   1: 5.50%
#
# [Cluster 1 - chungcheong (Raw Ratio)]
#   0: 99.62%
#   1: 0.38%
#
# [Cluster 2 - chungcheong (Raw Ratio)]
#   0: 99.81%
#   1: 0.19%
#
# [Cluster 3 - chungcheong (Raw Ratio)]
#   0: 99.52%
#   1: 0.48%
#
# [Cluster 4 - chungcheong (Raw Ratio)]
#   0: 96.88%
#   1: 3.12%
#
# [Cluster 5 - chungcheong (Raw Ratio)]
#   0: 95.11%
#   1: 4.89%
#
# [Cluster 6 - chungcheong (Raw Ratio)]
#   0: 95.51%
#   1: 4.49%
#
# === Analyzing Column: gyeongsang ===
#
# [Cluster 0 - gyeongsang (Raw Ratio)]
#   0: 62.33%
#   1: 37.67%
#
# [Cluster 1 - gyeongsang (Raw Ratio)]
#   0: 92.36%
#   1: 7.64%
#
# [Cluster 2 - gyeongsang (Raw Ratio)]
#   0: 93.12%
#   1: 6.88%
#
# [Cluster 3 - gyeongsang (Raw Ratio)]
#   0: 91.95%
#   1: 8.05%
#
# [Cluster 4 - gyeongsang (Raw Ratio)]
#   0: 81.18%
#   1: 18.82%
#
# [Cluster 5 - gyeongsang (Raw Ratio)]
#   0: 52.94%
#   1: 47.06%
#
# [Cluster 6 - gyeongsang (Raw Ratio)]
#   0: 51.34%
#   1: 48.66%
#
# === Analyzing Column: jeolla ===
#
# [Cluster 0 - jeolla (Raw Ratio)]
#   0: 93.80%
#   1: 6.20%
#
# [Cluster 1 - jeolla (Raw Ratio)]
#   0: 99.67%
#   1: 0.33%
#
# [Cluster 2 - jeolla (Raw Ratio)]
#   0: 99.77%
#   1: 0.23%
#
# [Cluster 3 - jeolla (Raw Ratio)]
#   0: 99.71%
#   1: 0.29%
#
# [Cluster 4 - jeolla (Raw Ratio)]
#   0: 97.44%
#   1: 2.56%
#
# [Cluster 5 - jeolla (Raw Ratio)]
#   0: 92.54%
#   1: 7.46%
#
# [Cluster 6 - jeolla (Raw Ratio)]
#   0: 93.05%
#   1: 6.95%
#
# === Analyzing Column: jeju ===
#
# [Cluster 0 - jeju (Raw Ratio)]
#   0: 84.99%
#   1: 15.01%
#
# [Cluster 1 - jeju (Raw Ratio)]
#   0: 93.54%
#   1: 6.46%
#
# [Cluster 2 - jeju (Raw Ratio)]
#   0: 93.22%
#   1: 6.78%
#
# [Cluster 3 - jeju (Raw Ratio)]
#   0: 94.16%
#   1: 5.84%
#
# [Cluster 4 - jeju (Raw Ratio)]
#   0: 91.27%
#   1: 8.73%
#
# [Cluster 5 - jeju (Raw Ratio)]
#   0: 83.71%
#   1: 16.29%
#
# [Cluster 6 - jeju (Raw Ratio)]
#   0: 84.21%
#   1: 15.79%
#
# === Analyzing Column: planned_activity ===
#
# [Cluster 0 - planned_activity (Mapped Categorical)]
#   문화/역사/자연: 24.41%
#   음식/미식: 22.06%
#   쇼핑: 18.36%
#   기타: 16.51%
#   뷰티/휴식/의료: 8.05%
#   한류/공연: 6.65%
#   유흥/오락: 2.05%
#   현대문화: 1.05%
#   스포츠/레저: 0.85%
#
# [Cluster 1 - planned_activity (Mapped Categorical)]
#   음식/미식: 28.40%
#   문화/역사/자연: 27.21%
#   쇼핑: 15.10%
#   기타: 11.16%
#   뷰티/휴식/의료: 9.16%
#   유흥/오락: 4.08%
#   한류/공연: 2.71%
#   현대문화: 1.47%
#   스포츠/레저: 0.71%
#
# [Cluster 2 - planned_activity (Mapped Categorical)]
#   음식/미식: 27.29%
#   문화/역사/자연: 24.85%
#   쇼핑: 19.45%
#   한류/공연: 7.97%
#   기타: 7.84%
#   뷰티/휴식/의료: 7.39%
#   유흥/오락: 2.96%
#   현대문화: 1.77%
#   스포츠/레저: 0.48%
#
# [Cluster 3 - planned_activity (Mapped Categorical)]
#   음식/미식: 32.81%
#   쇼핑: 30.50%
#   기타: 9.59%
#   한류/공연: 9.04%
#   문화/역사/자연: 8.89%
#   뷰티/휴식/의료: 5.14%
#   현대문화: 1.95%
#   유흥/오락: 1.80%
#   스포츠/레저: 0.26%
#
# [Cluster 4 - planned_activity (Mapped Categorical)]
#   음식/미식: 31.65%
#   쇼핑: 21.14%
#   기타: 20.28%
#   문화/역사/자연: 12.27%
#   뷰티/휴식/의료: 5.51%
#   한류/공연: 3.47%
#   유흥/오락: 2.88%
#   현대문화: 1.53%
#   스포츠/레저: 1.28%
#
# [Cluster 5 - planned_activity (Mapped Categorical)]
#   문화/역사/자연: 43.82%
#   음식/미식: 15.34%
#   기타: 13.23%
#   뷰티/휴식/의료: 9.70%
#   쇼핑: 8.50%
#   유흥/오락: 4.02%
#   한류/공연: 2.57%
#   현대문화: 1.53%
#   스포츠/레저: 1.29%
#
# [Cluster 6 - planned_activity (Mapped Categorical)]
#   문화/역사/자연: 36.63%
#   음식/미식: 17.79%
#   기타: 12.48%
#   쇼핑: 11.29%
#   뷰티/휴식/의료: 9.10%
#   한류/공연: 6.24%
#   유흥/오락: 3.57%
#   현대문화: 2.08%
#   스포츠/레저: 0.82%
#
# === Analyzing Column: total_duration ===
#
# [Cluster-wise Mean of 'total_duration']
#   Cluster 0: 10.41
#   Cluster 1: 6.74
#   Cluster 2: 6.57
#   Cluster 3: 5.83
#   Cluster 4: 8.30
#   Cluster 5: 10.04
#   Cluster 6: 10.17
#
# === Analyzing Column: total_expense ===
#
# [Cluster-wise Mean of 'total_expense']
#   Cluster 0: 1549.13
#   Cluster 1: 2240.77
#   Cluster 2: 5519.52
#   Cluster 3: 1801.77
#   Cluster 4: 2256.41
#   Cluster 5: 1853.46
#   Cluster 6: 1919.65
#
# === Analyzing Column: accommodation_cost ===
#
# [Cluster-wise Mean of 'accommodation_cost']
#   Cluster 0: 364.48
#   Cluster 1: 795.31
#   Cluster 2: 1704.01
#   Cluster 3: 272.43
#   Cluster 4: 410.29
#   Cluster 5: 527.46
#   Cluster 6: 455.07
#
# === Analyzing Column: food_cost ===
#
# [Cluster-wise Mean of 'food_cost']
#   Cluster 0: 536.50
#   Cluster 1: 677.32
#   Cluster 2: 2297.14
#   Cluster 3: 995.16
#   Cluster 4: 1110.98
#   Cluster 5: 411.11
#   Cluster 6: 568.07
#
# === Analyzing Column: shopping_cost ===
#
# [Cluster-wise Mean of 'shopping_cost']
#   Cluster 0: 297.55
#   Cluster 1: 413.42
#   Cluster 2: 958.19
#   Cluster 3: 252.57
#   Cluster 4: 365.17
#   Cluster 5: 351.00
#   Cluster 6: 287.83
#
# === Analyzing Column: accommodation_percent ===
#
# [Cluster-wise Mean of 'accommodation_percent']
#   Cluster 0: 0.24
#   Cluster 1: 0.27
#   Cluster 2: 0.24
#   Cluster 3: 0.21
#   Cluster 4: 0.23
#   Cluster 5: 0.28
#   Cluster 6: 0.26
#
# === Analyzing Column: food_percent ===
#
# [Cluster-wise Mean of 'food_percent']
#   Cluster 0: 0.35
#   Cluster 1: 0.32
#   Cluster 2: 0.36
#   Cluster 3: 0.47
#   Cluster 4: 0.39
#   Cluster 5: 0.25
#   Cluster 6: 0.27
#
# === Analyzing Column: shopping_percent ===
#
# [Cluster-wise Mean of 'shopping_percent']
#   Cluster 0: 0.21
#   Cluster 1: 0.20
#   Cluster 2: 0.19
#   Cluster 3: 0.17
#   Cluster 4: 0.21
#   Cluster 5: 0.20
#   Cluster 6: 0.19
#
# === Analyzing Column: food ===
#
# [Cluster-wise Mean of 'food']
#   Cluster 0: 4.43
#   Cluster 1: 4.39
#   Cluster 2: 4.42
#   Cluster 3: 4.38
#   Cluster 4: 4.38
#   Cluster 5: 4.43
#   Cluster 6: 4.45
#
# === Analyzing Column: landscape ===
#
# [Cluster-wise Mean of 'landscape']
#   Cluster 0: 4.46
#   Cluster 1: 4.48
#   Cluster 2: 4.46
#   Cluster 3: 4.34
#   Cluster 4: 4.38
#   Cluster 5: 4.57
#   Cluster 6: 4.60
#
# === Analyzing Column: heritage ===
#
# [Cluster-wise Mean of 'heritage']
#   Cluster 0: 4.46
#   Cluster 1: 4.48
#   Cluster 2: 4.47
#   Cluster 3: 4.35
#   Cluster 4: 4.38
#   Cluster 5: 4.56
#   Cluster 6: 4.58
#
# === Analyzing Column: language ===
#
# [Cluster-wise Mean of 'language']
#   Cluster 0: 4.04
#   Cluster 1: 4.00
#   Cluster 2: 4.06
#   Cluster 3: 4.09
#   Cluster 4: 3.95
#   Cluster 5: 3.97
#   Cluster 6: 4.04
#
# === Analyzing Column: safety ===
#
# [Cluster-wise Mean of 'safety']
#   Cluster 0: 4.36
#   Cluster 1: 4.34
#   Cluster 2: 4.36
#   Cluster 3: 4.29
#   Cluster 4: 4.35
#   Cluster 5: 4.42
#   Cluster 6: 4.42
#
# === Analyzing Column: budget ===
#
# [Cluster-wise Mean of 'budget']
#   Cluster 0: 3.94
#   Cluster 1: 3.96
#   Cluster 2: 4.04
#   Cluster 3: 4.02
#   Cluster 4: 3.92
#   Cluster 5: 3.96
#   Cluster 6: 4.01
#
# === Analyzing Column: accommodation ===
#
# [Cluster-wise Mean of 'accommodation']
#   Cluster 0: 4.37
#   Cluster 1: 4.36
#   Cluster 2: 4.39
#   Cluster 3: 4.35
#   Cluster 4: 4.34
#   Cluster 5: 4.39
#   Cluster 6: 4.41
#
# === Analyzing Column: transport ===
#
# [Cluster-wise Mean of 'transport']
#   Cluster 0: 4.40
#   Cluster 1: 4.42
#   Cluster 2: 4.40
#   Cluster 3: 4.34
#   Cluster 4: 4.38
#   Cluster 5: 4.48
#   Cluster 6: 4.45
#
# === Analyzing Column: navigation ===
#
# [Cluster-wise Mean of 'navigation']
#   Cluster 0: 4.26
#   Cluster 1: 4.24
#   Cluster 2: 4.26
#   Cluster 3: 4.25
#   Cluster 4: 4.23
#   Cluster 5: 4.25
#   Cluster 6: 4.27

# %%
summary_rows = []

for column in columns_to_analyze:
    if column in all_reverse_mappings:
        # 매핑 후 범주형 비율 출력
        mapper = all_reverse_mappings[column]
        output_df_clean_2[column] = pd.to_numeric(output_df_clean_2[column], errors='coerce')
        output_df_clean_2[column] = output_df_clean_2[column].map(mapper)

        cluster_groups = output_df_clean_2.groupby(groupby_col)[column]
        for cluster_id, group in cluster_groups:
            value_counts = group.value_counts(normalize=True, dropna=True) * 100
            for value, percent in value_counts.items():
                summary_rows.append({
                    'cluster': cluster_id,
                    'variable': column,
                    'category_or_range': value,
                    'value_type': 'categorical',
                    'value': percent
                })

    elif column in mean_cols and column in output_df_clean.columns:
        # 숫자형 평균 출력
        mean_by_cluster = output_df_clean.groupby(groupby_col)[column].mean()
        for cluster_id, mean_value in mean_by_cluster.items():
            summary_rows.append({
                'cluster': cluster_id,
                'variable': column,
                'category_or_range': 'mean',
                'value_type': 'mean',
                'value': mean_value
            })

    else:
        # 매핑도 평균도 아니면 원본값으로 비율 출력
        cluster_groups = output_df_clean_2.groupby(groupby_col)[column]
        for cluster_id, group in cluster_groups:
            value_counts = group.value_counts(normalize=True, dropna=True) * 100
            for value, percent in value_counts.items():
                summary_rows.append({
                    'cluster': cluster_id,
                    'variable': column,
                    'category_or_range': value,
                    'value_type': 'raw_ratio',
                    'value': percent
                })

# 결과를 DataFrame으로 변환
summary_df = pd.DataFrame(summary_rows)

# 미리보기
print(summary_df)
# Out:
#      cluster    variable category_or_range value_type      value
# 0          0       month                10  raw_ratio  10.055028
# 1          0       month                 2  raw_ratio   9.254627
# 2          0       month                 9  raw_ratio   9.254627
# 3          0       month                11  raw_ratio   8.854427
# 4          0       month                12  raw_ratio   8.854427
# ..       ...         ...               ...        ...        ...
# 390        2  navigation              mean       mean   4.261331
# 391        3  navigation              mean       mean   4.246154
# 392        4  navigation              mean       mean   4.233276
# 393        5  navigation              mean       mean   4.252488
# 394        6  navigation              mean       mean   4.272288
#
# [395 rows x 5 columns]

# %%
demographic_cols = ['country', 'gender', 'age']
regions_cols = ["seoul", "gyeonggi", "incheon", "gangwon", "chungcheong", "gyeongsang", "jeolla", "jeju"]
behaviour_cols = ["planned_activity", 'total_duration', 'total_expense', 'accommodation_percent', 'food_percent', 'shopping_percent']
satisfaction_cols = ['satisfaction', 'revisit_intent', 'recommend_intent'
                     , 'food', 'landscape', 'heritage', 'language', 'safety', 'budget'
                     , 'accommodation', 'transport', 'navigation']

# %%
from sklearn.preprocessing import StandardScaler
import pandas as pd

# 그룹 정의
all_groups = {
    'demographic': demographic_cols,
    'region': regions_cols,
    'behavior': behaviour_cols,
    'satisfaction': satisfaction_cols
}

# 1. 분석용 복사
df = output_df_clean.copy()
df = df.dropna(subset=sum(all_groups.values(), []) + ['cluster'])  # 모든 그룹 변수 + cluster 기준 결측 제거

# 2. 전체 표준화
scaler = StandardScaler()
z_all = pd.DataFrame(scaler.fit_transform(df[sum(all_groups.values(), [])]), 
                     columns=sum(all_groups.values(), []))
z_all['cluster'] = df['cluster'].values

# 3. 그룹별 클러스터 특징 추출
top_n = 3  # 클러스터별 Top N 변수

for group_name, cols in all_groups.items():
    print(f"\n\n🔷 [Group: {group_name.upper()}]")

    # 그룹 변수만 추출
    z_group = z_all[cols + ['cluster']]

    # 클러스터별 평균 Z-score
    cluster_means = z_group.groupby('cluster').mean()

    # 클러스터별 Top/Bottom 변수 출력
    for cluster_id in cluster_means.index:
        print(f"\n📌 Cluster {cluster_id} - 상위 {top_n} 변수:")
        top_vars = cluster_means.loc[cluster_id].sort_values(ascending=False).head(top_n)
        for var, score in top_vars.items():
            print(f"  ▲ {var}: {score:.2f}")

        print(f"🔻 Cluster {cluster_id} - 하위 {top_n} 변수:")
        bottom_vars = cluster_means.loc[cluster_id].sort_values().head(top_n)
        for var, score in bottom_vars.items():
            print(f"  ▼ {var}: {score:.2f}")
# Out:
# 🔷 [Group: DEMOGRAPHIC]
#
# 📌 Cluster 0 - 상위 3 변수:
#   ▲ gender: 0.79
#   ▲ age: 0.12
#   ▲ country: -0.08
# 🔻 Cluster 0 - 하위 3 변수:
#   ▼ country: -0.08
#   ▼ age: 0.12
#   ▼ gender: 0.79
#
# 📌 Cluster 1 - 상위 3 변수:
#   ▲ country: 0.13
#   ▲ age: -0.07
#   ▲ gender: -1.27
# 🔻 Cluster 1 - 하위 3 변수:
#   ▼ gender: -1.27
#   ▼ age: -0.07
#   ▼ country: 0.13
#
# 📌 Cluster 2 - 상위 3 변수:
#   ▲ gender: 0.79
#   ▲ country: 0.00
#   ▲ age: -0.13
# 🔻 Cluster 2 - 하위 3 변수:
#   ▼ age: -0.13
#   ▼ country: 0.00
#   ▼ gender: 0.79
#
# 📌 Cluster 3 - 상위 3 변수:
#   ▲ gender: 0.79
#   ▲ age: -0.03
#   ▲ country: -0.19
# 🔻 Cluster 3 - 하위 3 변수:
#   ▼ country: -0.19
#   ▼ age: -0.03
#   ▼ gender: 0.79
#
# 📌 Cluster 4 - 상위 3 변수:
#   ▲ age: 0.26
#   ▲ country: -0.06
#   ▲ gender: -1.27
# 🔻 Cluster 4 - 하위 3 변수:
#   ▼ gender: -1.27
#   ▼ country: -0.06
#   ▼ age: 0.26
#
# 📌 Cluster 5 - 상위 3 변수:
#   ▲ country: 0.17
#   ▲ age: -0.01
#   ▲ gender: -1.27
# 🔻 Cluster 5 - 하위 3 변수:
#   ▼ gender: -1.27
#   ▼ age: -0.01
#   ▼ country: 0.17
#
# 📌 Cluster 6 - 상위 3 변수:
#   ▲ gender: 0.79
#   ▲ country: 0.16
#   ▲ age: -0.11
# 🔻 Cluster 6 - 하위 3 변수:
#   ▼ age: -0.11
#   ▼ country: 0.16
#   ▼ gender: 0.79
#
#
# 🔷 [Group: REGION]
#
# 📌 Cluster 0 - 상위 3 변수:
#   ▲ gyeonggi: 0.51
#   ▲ gangwon: 0.46
#   ▲ gyeongsang: 0.35
# 🔻 Cluster 0 - 하위 3 변수:
#   ▼ seoul: -0.02
#   ▼ jeju: 0.16
#   ▼ jeolla: 0.18
#
# 📌 Cluster 1 - 상위 3 변수:
#   ▲ seoul: -0.05
#   ▲ jeju: -0.12
#   ▲ chungcheong: -0.13
# 🔻 Cluster 1 - 하위 3 변수:
#   ▼ gyeonggi: -0.37
#   ▼ gyeongsang: -0.36
#   ▼ gangwon: -0.36
#
# 📌 Cluster 2 - 상위 3 변수:
#   ▲ seoul: -0.01
#   ▲ jeju: -0.11
#   ▲ chungcheong: -0.15
# 🔻 Cluster 2 - 하위 3 변수:
#   ▼ gyeonggi: -0.39
#   ▼ gyeongsang: -0.38
#   ▼ gangwon: -0.37
#
# 📌 Cluster 3 - 상위 3 변수:
#   ▲ seoul: -0.04
#   ▲ chungcheong: -0.13
#   ▲ jeju: -0.14
# 🔻 Cluster 3 - 하위 3 변수:
#   ▼ gyeonggi: -0.37
#   ▼ gangwon: -0.36
#   ▼ gyeongsang: -0.35
#
# 📌 Cluster 4 - 상위 3 변수:
#   ▲ chungcheong: 0.04
#   ▲ incheon: 0.04
#   ▲ jeolla: -0.03
# 🔻 Cluster 4 - 하위 3 변수:
#   ▼ seoul: -0.13
#   ▼ gyeongsang: -0.10
#   ▼ gangwon: -0.07
#
# 📌 Cluster 5 - 상위 3 변수:
#   ▲ gyeongsang: 0.57
#   ▲ gangwon: 0.54
#   ▲ gyeonggi: 0.52
# 🔻 Cluster 5 - 하위 3 변수:
#   ▼ seoul: 0.15
#   ▼ chungcheong: 0.16
#   ▼ jeju: 0.20
#
# 📌 Cluster 6 - 상위 3 변수:
#   ▲ gyeongsang: 0.61
#   ▲ gangwon: 0.52
#   ▲ gyeonggi: 0.49
# 🔻 Cluster 6 - 하위 3 변수:
#   ▼ chungcheong: 0.13
#   ▼ seoul: 0.14
#   ▼ jeju: 0.19
#
#
# 🔷 [Group: BEHAVIOR]
#
# 📌 Cluster 0 - 상위 3 변수:
#   ▲ total_duration: 0.32
#   ▲ planned_activity: 0.11
#   ▲ shopping_percent: 0.10
# 🔻 Cluster 0 - 하위 3 변수:
#   ▼ food_percent: -0.05
#   ▼ accommodation_percent: -0.04
#   ▼ total_expense: -0.01
#
# 📌 Cluster 1 - 상위 3 변수:
#   ▲ accommodation_percent: 0.16
#   ▲ shopping_percent: 0.07
#   ▲ total_expense: -0.00
# 🔻 Cluster 1 - 하위 3 변수:
#   ▼ total_duration: -0.17
#   ▼ food_percent: -0.16
#   ▼ planned_activity: -0.04
#
# 📌 Cluster 2 - 상위 3 변수:
#   ▲ total_expense: 0.04
#   ▲ food_percent: 0.00
#   ▲ accommodation_percent: -0.01
# 🔻 Cluster 2 - 하위 3 변수:
#   ▼ total_duration: -0.19
#   ▼ planned_activity: -0.15
#   ▼ shopping_percent: -0.05
#
# 📌 Cluster 3 - 상위 3 변수:
#   ▲ food_percent: 0.51
#   ▲ total_expense: -0.01
#   ▲ planned_activity: -0.09
# 🔻 Cluster 3 - 하위 3 변수:
#   ▼ total_duration: -0.29
#   ▼ accommodation_percent: -0.22
#   ▼ shopping_percent: -0.18
#
# 📌 Cluster 4 - 상위 3 변수:
#   ▲ planned_activity: 0.23
#   ▲ shopping_percent: 0.15
#   ▲ food_percent: 0.13
# 🔻 Cluster 4 - 하위 3 변수:
#   ▼ accommodation_percent: -0.06
#   ▼ total_expense: -0.00
#   ▼ total_duration: 0.04
#
# 📌 Cluster 5 - 상위 3 변수:
#   ▲ total_duration: 0.27
#   ▲ accommodation_percent: 0.24
#   ▲ shopping_percent: 0.05
# 🔻 Cluster 5 - 하위 3 변수:
#   ▼ food_percent: -0.46
#   ▼ total_expense: -0.01
#   ▼ planned_activity: 0.01
#
# 📌 Cluster 6 - 상위 3 변수:
#   ▲ total_duration: 0.28
#   ▲ accommodation_percent: 0.10
#   ▲ shopping_percent: -0.00
# 🔻 Cluster 6 - 하위 3 변수:
#   ▼ food_percent: -0.37
#   ▼ planned_activity: -0.01
#   ▼ total_expense: -0.01
#
#
# 🔷 [Group: SATISFACTION]
#
# 📌 Cluster 0 - 상위 3 변수:
#   ▲ revisit_intent: 0.17
#   ▲ recommend_intent: 0.11
#   ▲ satisfaction: 0.03
# 🔻 Cluster 0 - 하위 3 변수:
#   ▼ budget: -0.05
#   ▼ transport: -0.00
#   ▼ accommodation: 0.00
#
# 📌 Cluster 1 - 상위 3 변수:
#   ▲ heritage: 0.04
#   ▲ landscape: 0.04
#   ▲ satisfaction: 0.03
# 🔻 Cluster 1 - 하위 3 변수:
#   ▼ revisit_intent: -0.16
#   ▼ recommend_intent: -0.05
#   ▼ language: -0.03
#
# 📌 Cluster 2 - 상위 3 변수:
#   ▲ budget: 0.06
#   ▲ language: 0.04
#   ▲ accommodation: 0.02
# 🔻 Cluster 2 - 하위 3 변수:
#   ▼ recommend_intent: -0.08
#   ▼ revisit_intent: -0.08
#   ▼ satisfaction: -0.02
#
# 📌 Cluster 3 - 상위 3 변수:
#   ▲ revisit_intent: 0.08
#   ▲ language: 0.07
#   ▲ budget: 0.04
# 🔻 Cluster 3 - 하위 3 변수:
#   ▼ landscape: -0.17
#   ▼ heritage: -0.16
#   ▼ recommend_intent: -0.13
#
# 📌 Cluster 4 - 상위 3 변수:
#   ▲ revisit_intent: 0.08
#   ▲ safety: -0.01
#   ▲ navigation: -0.02
# 🔻 Cluster 4 - 하위 3 변수:
#   ▼ landscape: -0.11
#   ▼ heritage: -0.11
#   ▼ satisfaction: -0.09
#
# 📌 Cluster 5 - 상위 3 변수:
#   ▲ landscape: 0.16
#   ▲ heritage: 0.15
#   ▲ recommend_intent: 0.13
# 🔻 Cluster 5 - 하위 3 변수:
#   ▼ revisit_intent: -0.11
#   ▼ language: -0.06
#   ▼ budget: -0.03
#
# 📌 Cluster 6 - 상위 3 변수:
#   ▲ landscape: 0.21
#   ▲ recommend_intent: 0.21
#   ▲ heritage: 0.18
# 🔻 Cluster 6 - 하위 3 변수:
#   ▼ revisit_intent: -0.01
#   ▼ language: 0.01
#   ▼ navigation: 0.03

# %%
print('hi')

new_data = pd.DataFrame([{
    'gender': '여성',
    'age': 45,
    'purpose': '문화',
    'season': '가을',
    'spend_total': 1200000,
    'stay_duration': 5
}])
# Out:
# hi
